# %%
node_names = ["Location","Event","Drug","Recall","Patient","Safety_And_Toxicology","Treatment_Composition","Indications"]


     
abbreviations = {
    'Location': 'Loc',
    'Event': 'Eve',
    'Drug': 'Dru',
    'Recall': 'Rec',
    'Patient': 'Pat',
    'Safety_And_Toxicology': 'Saf',
    'Treatment_Composition': 'Tre',
    'Indications': 'Ind'
}

relationships = {
    'Location': 'in_locations',
    'Event': 'CONTAINS_DRUG_INFO',
    'Recall': 'RELATED_DRUGS',
    'Patient': 'PARTICIPATED_IN',
    'Safety_And_Toxicology': 'HAS_SAFTY_INFO',
    'Treatment_Composition': 'HAS_Treatment_INFO',
    'Indications': 'Has-Indication-info'
}

rel_directions = {
    'Location': ['-','->'],
    'Event': ['-','->'],
    'Recall': ['-','->'],
    'Patient': ['-','->'],
    'Safety_And_Toxicology': ['-','->'],
    'Treatment_Composition': ['-','->'],
    'Indications': ['-','->']
}

 

fields = {
    'Location': ["address_1", "address_2", "city", "country", "state"],

    'Event': ["primarysource_literaturereference", "primarysource_qualification", "primarysource_reportercountry",
              "primarysourcecountry", "serious", "seriousnesscongenitalanomali", "seriousnessdisabling",
              "seriousnesshospitalization", "seriousnesslifethreatening", "seriousnessother", "safetyreportid", 
              "seriousnessdeath", "companynumb", "fulfillexpeditecriteria", "receivedateformat",
              "receiver_receiverorganization", "receiver_receivertype", "reportduplicate_duplicatenumb", 
              "reportduplicate_duplicatesource", "reporttype", "sender_senderorganization", "sender_sendertype", 
              "receiptdate", "receiptdateformat", "receivedate", "safetyreportversion", "transmissiondate",
              "transmissiondateformat", "duplicate"],
    
    'Drug': ["brand_name", "brand_name_base", "brand_name_suffix", "description", "dosage_and_administration",
             "dosage_form", "dosage_forms_and_strengths", "generic_name", "indications_and_usage", 
             "instructions_for_use", "laboratory_tests", "mechanism_of_action", "package_label_principal_display_panel",
             "pharm_class", "pharmacodynamics", "pharmacogenomics", "pharmacokinetics", "product_code",
             "product_description", "product_id", "product_ndc", "product_quantity", "products_brand_name",
             "products_dosage_form", "products_marketing_status", "products_product_number", "products_reference_drug",
             "products_reference_standard", "products_route", "products_te_code", "ask_doctor_or_pharmacist",
             "drug_and_or_laboratory_test_interactions", "drug_interactions", "route", "information_for_patients",
             "patient_medication_information", "spl_medguide", "spl_patient_package_insert", "purpose", 
             "disposal_and_waste_handling", "product_type",              
              #Open_FDA
             "openfda_application_number", "openfda_brand_name", "openfda_generic_name", "openfda_is_original_packager",
              "openfda_nui", "openfda_pharm_class_cs", "openfda_pharm_class_epc", "openfda_pharm_class_moa", 
              "openfda_pharm_class_pe", "openfda_product_ndc", "openfda_product_type", "openfda_route",
              "openfda_spl_id", "openfda_spl_set_id", "openfda_unii", "openfda_upc", "openfda_rxcui",
              "openfda_substance_name", "openfda_manufacturer_name"],

    'Recall': ["classification", "reason_for_recall", "recall_initiation_date", "recall_number",
               "recalling_firm", "status", "voluntary_mandated", "center_classification_date", "code_info", 
               "distribution_pattern", "event_id", "initial_firm_notification", "report_date", "termination_date"],

    'Patient': ["patient_patientagegroup", "patient_patientdeath_date", "patient_patientdeath_format",
                "patient_patientonsetage", "patient_patientonsetageunit", "patient_patientsex", 
                "patient_patientweight", "patient_reaction", "patient_summary"],

    'Safety_And_Toxicology': [#Abuse_and_Overdosage
                             "abuse", "dependence", "drug_abuse_and_dependence", "overdosage",
                              #Clinical_Pharmacology
                             "clinical_pharmacology", "clinical_studies",
                              #Safety_and_Adverse_Effects
                              "adverse_reactions", "ask_doctor", "risks", "troubleshooting", "warnings", 
                              "warnings_and_cautions", "when_using",
                              #Warnings_and_Precautions
                              "alarms", "boxed_warning", "environmental_warning", "food_safety_warning", 
                              "general_precautions", "keep_out_of_reach_of_children", "nonteratogenic_effects",
                              "other_safety_information", "precautions", "statement_of_identity", 
                              "stop_use", "user_safety_warnings",
                              #Use_in_Specific_Populations
                              "geriatric_use", "labor_and_delivery", "nursing_mothers", "pediatric_use", 
                              "pregnancy", "pregnancy_or_breast_feeding", "teratogenic_effects", "use_in_specific_populations",
                               #Nonclinical_toxicology
                              "animal_pharmacology_and_or_toxicology", "carcinogenesis_and_mutagenesis_and_impairment_of_fertility",
                              "nonclinical_toxicology"],

    'Treatment_Composition': [#Active_Ingredients
                              "active_ingredient", "inactive_ingredient", "spl_product_data_elements", 
                              "active_ingredient_name", "active_ingredient_strength",
                              #contraindications
                              "contraindications", "do_not_use"],

    'Indications': []

}

#Documentation_and_Additional_Information:
#["accessories", "assembly_or_installation_instructions", "cleaning", "diagram_of_device", 
#"effective_time", "guaranteed_analysis_of_feed", "health_care_provider_letter", "health_claim", 
#"information_for_owners_or_caregivers", "intended_use_of_the_device", "microbiology",
#"summary_of_safety_and_effectiveness", "questions", "recent_major_changes", "references", 
#"spl_indexing_data_elements", "spl_unclassified_section", "version", "set_id"]

#Marketing_and_Product_Lifecycle:
#["finished", "listing_expiration_date", "marketing_category", "marketing_end_date", "marketing_start_date",
#"packaging_description", "packaging_marketing_end_date", "packaging_marketing_start_date", 
#"packaging_package_ndc", "packaging_sample", "application_number", "dea_schedule"]


#Supply_storage_and_handling:
#["calibration_instructions", "components", "controlled_substance", "how_supplied",
#"safe_handling_warning", "storage_and_handling"]

# %%
import requests

def fetch_fda_data(api_url, params=None):
    try:
        response = requests.get(api_url, params=params)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from FDA API: {e}")
        return None

#event,label, ndc,enforcement,drugsfda
# Example usage:
api_url  = "https://api.fda.gov/drug/event.json"
#api_url  = "https://api.fda.gov/drug/event.json?search=receivedate:[20231101+TO+20231215]"
# You may need to adjust the parameters based on your specific requirements
api_params = {#parameters required by the API
    'api_key':'XWy4g4DSN4A3BYboNc7aCSlaxhUptDDnNKQ8VbCN'   , 
    'search': "headache",          
    #'search': "receivedate:[20231101+TO+20231215]" #'headache',#What to search for, in which fields. If you don’t specify a field to search, the API will search in every field.
    #'sort':  ,#Sort the results of the search by the specified field in ascending or descending order by using the :asc or :desc modifier.
    #'count': ,#Count the number of unique values of a certain field, for all the records that matched the search parameter. By default, the API returns the 1000 most frequent values.
    #'limit':10 ,#Return up to this number of records that match the search parameter. Currently, the largest allowed value for the limit parameter is 1000.
    #'skip':  ,#
    }

fda_data = fetch_fda_data(api_url, params=api_params)

if fda_data:
    # Process the fetched data as needed
    print(f"Successfully fetched data from FDA API: {fda_data}")
else:
    print("Failed to fetch data from FDA API. Check the error message for details.")

# %% [markdown]
# # Update

# %%
import requests

def fetch_fda_data(api_url, params=None):
    try:
        response = requests.get(api_url, params=params)
        response.raise_for_status() 
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from FDA API: {e}")
        return None
start_date = "20230801"
end_date = "20231215"
api_url  = "https://api.fda.gov/drug/event.json"
api_params = {
    'api_key':'XWy4g4DSN4A3BYboNc7aCSlaxhUptDDnNKQ8VbCN'   , 
    'search': f"receivedate:[{start_date} TO {end_date}]",          
    }

fda_data = fetch_fda_data(api_url, params=api_params)

if fda_data:
    # Process the fetched data as needed
    print(f"Successfully fetched data from FDA API: {fda_data}")
else:
    print("Failed to fetch data from FDA API. Check the error message for details.")
# Out:
# Successfully fetched data from FDA API: {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.', 'terms': 'https://open.fda.gov/terms/', 'license': 'https://open.fda.gov/license/', 'last_updated': '2023-11-09', 'results': {'skip': 0, 'limit': 1, 'total': 222073}}, 'results': [{'safetyreportversion': '1', 'safetyreportid': '22769417', 'primarysourcecountry': 'CA', 'occurcountry': 'CA', 'transmissiondateformat': '102', 'transmissiondate': '20231029', 'reporttype': '2', 'serious': '1', 'seriousnessdeath': '1', 'seriousnesslifethreatening': '2', 'seriousnesshospitalization': '2', 'seriousnessdisabling': '2', 'seriousnesscongenitalanomali': '2', 'seriousnessother': '2', 'receivedateformat': '102', 'receivedate': '20230801', 'receiptdateformat': '102', 'recei
# ...
