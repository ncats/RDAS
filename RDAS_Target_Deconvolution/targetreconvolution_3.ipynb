# %%
# !python -m pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.5

# %% [markdown]
# https://ftp.ncbi.nlm.nih.gov/pubchem/Compound/
#
# https://pubchem.ncbi.nlm.nih.gov/
#
# https://chembl.gitbook.io/chembl-interface-documentation/downloads
#
# https://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBLdb/latest/

# %%
#from chembl_webresource_client.new_client import new_client
from rdkit import Chem
from rdkit.Chem import MACCSkeys
from rdkit import DataStructs

def perform_similarity_search(compound_smiles, chembl_compounds, threshold=0.3):
    query_mol = Chem.MolFromSmiles(compound_smiles)
    query_fp = MACCSkeys.GenMACCSKeys(query_mol)

    similar_compounds = []
    # Iterate over compounds in ChEMBL and calculate similarity
    for molecule in chembl_compounds:
        try:
            smiles = molecule['molecule_structures']['canonical_smiles']
            mol = Chem.MolFromSmiles(smiles)
            if mol is not None:
                fp = MACCSkeys.GenMACCSKeys(mol)
                similarity = DataStructs.FingerprintSimilarity(query_fp, fp)
                if similarity >= threshold:
                    similar_compounds.append(molecule['molecule_chembl_id'])
        except KeyError:
            continue  # Skip this molecule if structure information is not available

    return similar_compounds

# %%
from rdkit import Chem
from rdkit.Chem import MACCSkeys, DataStructs

# Define a sample query compound SMILES string
query_smiles = 'CCO'

# Define a sample ChEMBL compounds list (just for demonstration)
chembl_compounds = [
    {'molecule_structures': {'canonical_smiles': 'CCOCO'}, 'molecule_chembl_id': 'CHEMBL1'},
    {'molecule_structures': {'canonical_smiles': 'CCN'}, 'molecule_chembl_id': 'CHEMBL2'},
    {'molecule_structures': {'canonical_smiles': 'CCC'}, 'molecule_chembl_id': 'CHEMBL3'}
]

# Define a threshold for similarity
threshold = 0.4

# Perform similarity search
similar_compounds = perform_similarity_search(query_smiles, chembl_compounds, threshold)

# Print the similar compounds found
print("Similar compounds:")
for compound in similar_compounds:
    print(compound)
# Out:
# Similar compounds:
# CHEMBL1

# %%
# !pip install chembl-webresource-client
# Out:
# Collecting chembl-webresource-client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl-webresource-client)
#   Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl-webresource-client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl-webresource-client)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl-webresource-client) (4.2.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl-webresource-client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl-webresource-client) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl-webresource-client) (4.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl-webresource-client) (1.16.0)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl-webresource-client
# Successfully installed cattrs-23.2.3 chembl-webresource-client-0.10.9 requests-cache-1.2.0 url-normalize-1.4.3

# %% [markdown]
# https://mybinder.org/v2/gh/chembl/chembl_webresource_client/master?filepath=demo_wrc.ipynb

# %%
from chembl_webresource_client.new_client import new_client

similarity = new_client.similarity
res = similarity.filter(smiles="CO[C@@H](CCC#C\C=C/CCCC(C)CCCCC=C)C(=O)[O-]", similarity=70).only(['molecule_chembl_id', 'similarity'])
for i in res:
    print(i)
# Out:
# {'molecule_chembl_id': 'CHEMBL478779', 'similarity': '85.4166686534881591796875'}
# {'molecule_chembl_id': 'CHEMBL477889', 'similarity': '85.4166686534881591796875'}
# {'molecule_chembl_id': 'CHEMBL477888', 'similarity': '85.4166686534881591796875'}
# {'molecule_chembl_id': 'CHEMBL2304268', 'similarity': '70.1754391193389892578125'}

# %%
from chembl_webresource_client.new_client import new_client

def perform_similarity_search(smiles, threshold=70):
    similarity = new_client.similarity
    # Perform similarity search using ChEMBL's similarity search API
    res = similarity.filter(smiles=smiles, similarity=threshold).only(['molecule_chembl_id', 'similarity'])
    similar_compounds = [(entry['molecule_chembl_id'],round(float(entry['similarity']),2)) for entry in res]
    similar_compounds_ = [entry['molecule_chembl_id'] for entry in res]
    return similar_compounds_

# Screening compounds with their IDs and SMILES strings
screening_compounds = {
    'NCGC00602080-03': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=C(F)C=CC=C4)N=C2C',
    'NCGC00685598-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC=CC=C4)N=C2C',
    'NCGC00685517-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC=CC(F)=C4)N=C2C',
    'NCGC00686269-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC(F)=CC(F)=C4)N=C2C'}

# Perform chemical structure similarity search against ChEMBL for each screening compound
similar_compounds_dict = {}
for compound_id, compound_smiles in screening_compounds.items():
    similar_compounds = perform_similarity_search(compound_smiles)
    print(similar_compounds)
    similar_compounds_dict[compound_id] = similar_compounds

similar_compounds_dict
# Out:
# []
# ['CHEMBL1409278']
# []
# []
# {'NCGC00602080-03': [],
#  'NCGC00685598-01': ['CHEMBL1409278'],
#  'NCGC00685517-01': [],
#  'NCGC00686269-01': []}

# %%
from chembl_webresource_client.new_client import new_client

def perform_connectivity_search(smiles, threshold=60):
    molecule = new_client.molecule
    # Perform similarity search using ChEMBL's similarity search API
    res = molecule.filter(molecule_structures__canonical_smiles__connectivity=smiles).only(['molecule_chembl_id', 'pref_name'])
    similar_compounds = [(entry['molecule_chembl_id'],entry['pref_name']) for entry in res]
    return similar_compounds

# Screening compounds with their IDs and SMILES strings
screening_compounds = {
    'NCGC00602080-03': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=C(F)C=CC=C4)N=C2C',
    'NCGC00685598-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC=CC=C4)N=C2C',
    'NCGC00685517-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC=CC(F)=C4)N=C2C',
    'NCGC00686269-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC(F)=CC(F)=C4)N=C2C'}

# Perform chemical structure similarity search against ChEMBL for each screening compound
similar_compounds_dict = {}
for compound_id, compound_smiles in screening_compounds.items():
    similar_compounds = perform_connectivity_search(compound_smiles)
    print(similar_compounds)
    similar_compounds_dict[compound_id] = similar_compounds
# Out:
# []
# []
# []
# []

# %%
from chembl_webresource_client.new_client import new_client

target = new_client.target
gene_name = 'BRD4'
res = target.filter(target_synonym__icontains=gene_name).only(['organism', 'pref_name', 'target_type'])
for i in res:
    print(i)
# Out:
# {'organism': 'Homo sapiens', 'pref_name': 'Bromodomain-containing protein 4', 'target_type': 'SINGLE PROTEIN'}
# {'organism': 'Mus musculus', 'pref_name': 'Bromodomain-containing protein 4', 'target_type': 'SINGLE PROTEIN'}
# {'organism': 'Homo sapiens', 'pref_name': 'BRD4/HDAC1', 'target_type': 'PROTEIN COMPLEX'}
# {'organism': 'Homo sapiens', 'pref_name': 'Cereblon/Cullin-4A/Bromodomain-containing protein 4', 'target_type': 'PROTEIN-PROTEIN INTERACTION'}
# {'organism': 'Homo sapiens', 'pref_name': 'Cereblon/Bromodomain-containing protein 4', 'target_type': 'PROTEIN-PROTEIN INTERACTION'}
# {'organism': 'Homo sapiens', 'pref_name': 'von Hippel-Lindau disease tumor suppressor/Bromodomain-containing protein 4', 'target_type': 'PROTEIN-PROTEIN INTERACTION'}
# {'organism': 'Homo sapiens', 'pref_name': 'Cereblon/DNA damage-binding protein 1/Bromodomain-containing protein 4', 'target_type': 'PROTEIN-PROTEIN INTERACTION'}
# {'organism': 'Homo sapiens', 'pref_name': 'von Hippel-Lindau disease tumor suppressor/Elongin-B/Elongin-C/Bromodomain-containing protein 4', 'target_type': 'PROTEIN-PROTEIN INTERACTION'}
# {'organism': 'Homo sapiens', 'pref_name': 'Bromodomain and extra-terminal motif (BET)', 'target_type': 'PROTEIN FAMILY'}
# {'organism': 'Homo sapiens', 'pref_name': 'BRD4/E3 ubiquitin-protein ligase Mdm2', 'target_type': 'PROTEIN-PROTEIN INTERACTION'}
# {'organism': 'Homo sapiens', 'pref_name': 'BRD4/E3 ubiquitin-protein ligase XIAP', 'target_type': 'PROTEIN-PROTEIN INTERACTION'}

# %%
from chembl_webresource_client.new_client import new_client
target = new_client.target
gene_name = 'CHEMBL1829'
res = target.filter(target=gene_name).only(['organism', 'pref_name', 'target_type'])
for i in res:
    print(i)

# %%
from chembl_webresource_client.new_client import new_client

def get_targets(chembl_ids):
    targets = set()
    target_client = new_client.target
    for chembl_id in chembl_ids:
        # Filter targets associated with the ChEMBL compound
        res = target_client.filter(target=chembl_id).only(['organism', 'pref_name', 'target_type'])
        for entry in res:
            targets.add((entry['organism'], entry['pref_name'], entry['target_type']))
    return targets

# Define the TOR1A target
TOR1A = 'CHEMBL1829'

# Get targets associated with ChEMBL compounds
chembl_targets = set()
for similar_compounds in similar_compounds_dict.values():
    chembl_targets.update(get_targets(similar_compounds))

# Compare ChEMBL targets with TOR1A to identify shared targets
shared_targets = [target for target in chembl_targets if target[0] == 'Homo sapiens' and target[1] == 'TOR1A']

# Print the shared targets
print("Shared targets associated with DYT1 (TOR1A):")
for target in shared_targets:
    print(target)

# %%
from chembl_webresource_client.new_client import new_client

def get_targets(chembl_ids):
    targets = set()
    target_client = new_client.target
    for chembl_id in chembl_ids:
        # Filter targets associated with the ChEMBL compound
        res = target_client.filter(target=chembl_id).only(['organism', 'pref_name', 'target_type'])
        for entry in res:
            targets.add((entry['organism'], entry['pref_name'], entry['target_type']))
    return targets

# Define the TOR1A target
TOR1A = 'CHEMBL1829'

# Get targets associated with ChEMBL compounds
chembl_targets = set()
for similar_compounds in similar_compounds_dict.values():
    chembl_targets.update(get_targets(similar_compounds))

# Compare ChEMBL targets with TOR1A to identify shared targets
shared_targets = [target for target in chembl_targets if target[0] == 'Homo sapiens' and target[1] == 'TOR1A']

# Print the shared targets
print("Shared targets associated with DYT1 (TOR1A):")
for target in shared_targets:
    print(target)

# %%
from chembl_webresource_client.new_client import new_client

# Function to retrieve targets associated with a ChEMBL ID
def get_gene_symbols(entry):
    gene_symbols = []
    for component in entry['target_components']:
        for synonym in component['target_component_synonyms']:
            if synonym['syn_type'] in ['GENE_SYMBOL', 'GENE_SYMBOL_OTHER']:
                gene_symbols.append(synonym['component_synonym'])
    return tuple(gene_symbols)  # Convert list to tuple

def get_targets(chembl_id):
    target_client = new_client.target
    # Retrieve targets associated with the ChEMBL ID
    res = target_client.filter(target=chembl_id).only(['target_chembl_id','organism','pref_name','target_components'])
    res = res[:100]
    # Extract the target ChEMBL IDs
    return {(entry['organism'], entry['target_chembl_id'], entry['pref_name'], get_gene_symbols(entry)) for entry in res}

    #return {(entry['organism'],entry['target_chembl_id'], entry['pref_name']) for entry in res}


# Function to find shared targets between two ChEMBL IDs
def find_shared_targets(chembl_id1, chembl_ids):
    # Retrieve targets associated with each ChEMBL ID
    targets1 = get_targets(chembl_id1)
    # Find the intersection of targets to get shared targets
    shared_targets = set()
    for chembl_id in chembl_ids:
        targets2 = get_targets(chembl_id)
        shared_targets.update(targets1.intersection(targets2))
    return shared_targets

# Get targets associated with ChEMBL compounds
chembl_targets = set()
for similar_compounds in similar_compounds_dict.values():
    chembl_targets.update(similar_compounds)

TOR1A = 'CHEMBL1829'  # Define the TOR1A target

# Find shared targets
shared_targets = find_shared_targets(TOR1A, chembl_targets)
print("Shared Targets:", list(shared_targets))  # Convert set to list for printing
# Out:
# Shared Targets: [('Homo sapiens', 'CHEMBL1843', 'DOPA decarboxylase', ('AADC', 'DDC', 'Synonyms=AADC')), ('Escherichia coli', 'CHEMBL1809', 'Dihydrofolate reductase', ('folA', 'tmrA ')), ('Homo sapiens', 'CHEMBL1952', 'Thymidylate synthase', ('TS', 'TYMS')), ('Homo sapiens', 'CHEMBL222', 'Norepinephrine transporter', ('NAT1', 'NET1', 'SLC6A2', 'SLC6A5')), ('Homo sapiens', 'CHEMBL2033', 'Cytochrome P450 11A1', ('CYP11A', 'CYP11A1', 'Synonyms=CYP11A')), ('Homo sapiens', 'CHEMBL211', 'Muscarinic acetylcholine receptor M2', ('CHRM2',)), ('Homo sapiens', 'CHEMBL1968', 'Epoxide hydrolase 1', ('EPHX', 'EPHX1', 'EPOX')), ('Homo sapiens', 'CHEMBL224', 'Serotonin 2a (5-HT2a) receptor', ('HTR2', 'HTR2A')), ('Homo sapiens', 'CHEMBL1994', 'Mineralocorticoid receptor', ('MCR', 'MLR', 'NR3C2')), ('Influenza A virus (A/Puerto Rico/8/1934(H1N1))', 'CHEMBL2051', 'Neuraminidase', ('NA',)), ('Homo sapiens', 'CHEMBL1848', 'Tubulin beta-2 chain', ('TUBB2C', 'TUBB4B')), ('Homo sapiens', 'CHEMBL209', 'Trypsin I', ('PRSS1', 'Synonyms=TRP1', 'TRP1', 'TRY1', 'TRYP1')), ('Homo sapiens', 'CHEMBL1812', 'Pancreatic lipase', ('PNLIP',)), ('Homo sapiens', 'CHEMBL1905', 'Fibronectin receptor beta', ('FNRB', 'ITGB1', 'MDF2', 'MSK12')), ('Homo sapiens', 'CHEMBL1981', 'Insulin receptor', ('INSR',)), ('Homo sapiens', 'CHEMBL204', 'Thrombin', ('F2',)), ('Homo sapiens', 'CHEMBL2000', 'Plasma kallikrein', ('KLK3', 'KLKB1')), ('Homo sapiens', 'CHEMBL1973', 'Tyrosinase', ('TYR',)), ('Homo sapiens', 'CHEMBL1898', 'Serotonin 1b (5-HT1b) receptor', ('HTR1B', 'HTR1DB')), ('Homo sapiens', 'CHEMBL1828', 'DNA polymerase alpha subunit', ('POLA', 'POLA1')), ('Homo sapiens', 'CHEMBL212', 'Integrin alpha-IIb', ('GP2B', 'ITGA2B', 'ITGAB')), ('Homo sapiens', 'CHEMBL1976', 'Growth hormone receptor', ('GHR',)), ('Homo sapiens', 'CHEMBL2024', 'Follicle stimulating hormone receptor', ('FSHR', 'LGR1')), ('Homo sapiens', 'CHEMBL1859', 'Voltage-gated T-type calcium channel alpha-1H subunit', ('CACNA1H',)), ('Homo sapiens', 'CHEMBL1910', 'Adenosine deaminase', ('ADA', 'ADA1')), ('Homo sapiens', 'CHEMBL1839', 'Thyroid peroxidase', ('TPO',)), ('Escherichia coli', 'CHEMBL2065', 'Beta-lactamase TEM', ('bla', 'blaT-3', 'blaT-4', 'blaT-5', 'blaT-6')), ('Homo sapiens', 'CHEMBL216', 'Muscarinic acetylcholine receptor M1', ('CHRM1',)), ('Ascaris suum', 'CHEMBL1884', 'Nicotinic acetylcholine receptor alpha subunit', ()), ('Homo sapiens', 'CHEMBL1801', 'Plasminogen', ('PLG',)), ('Escherichia coli K-12', 'CHEMBL1840', 'Penicillin-binding protein 2', ('mrdA', 'Synonyms=pbpA', 'Synonyms=pbpA {ECO:0000303|PubMed:3533535')), ('Homo sapiens', 'CHEMBL1902', 'FK506-binding protein 1A', ('FKBP1', 'FKBP12', 'FKBP1A')), ('Homo sapiens', 'CHEMBL2039', 'Monoamine oxidase B', ('MAOB',)), ('Homo sapiens', 'CHEMBL218', 'Cannabinoid CB1 receptor', ('CNR', 'CNR1')), ('Homo sapiens', 'CHEMBL1978', 'Cytochrome P450 19A1', ('ARO1', 'CYAR', 'CYP19', 'CYP19A1', 'Synonyms=ARO1')), ('Homo sapiens', 'CHEMBL203', 'Epidermal growth factor receptor erbB1', ('EGFR', 'ERBB', 'ERBB1', 'HER1')), ('Homo sapiens', 'CHEMBL1935', 'Aldehyde dehydrogenase', ('ALDH2', 'ALDM')), ('Homo sapiens', 'CHEMBL1782', 'Farnesyl diphosphate synthase', ('FDPS', 'FPS', 'KIAA1293')), ('Homo sapiens', 'CHEMBL1807', 'Sodium/potassium-transporting ATPase alpha-1 chain', ('ATP1A1',)), ('Homo sapiens', 'CHEMBL210', 'Beta-2 adrenergic receptor', ('ADRB2', 'ADRB2R', 'B2AR')), ('Homo sapiens', 'CHEMBL1787', 'Steroid 5-alpha-reductase 1', ('SRD5A1',)), ('Plasmodium falciparum K1', 'CHEMBL1939', 'Dihydrofolate reductase', ()), ('Homo sapiens', 'CHEMBL1846', 'Ryanodine receptor 1', ('RYDR', 'RYR1')), ('Homo sapiens', 'CHEMBL202', 'Dihydrofolate reductase', ('DHFR',)), ('Homo sapiens', 'CHEMBL2074', 'Maltase-glucoamylase', ('MGA', 'MGAM', 'MGAML', 'Synonyms=MGA')), ('Escherichia coli K-12', 'CHEMBL1984', 'UDP-N-acetylglucosamine 1-carboxyvinyltransferase', ('murA', 'murZ')), ('Escherichia coli K-12', 'CHEMBL1858', 'DNA gyrase subunit A', ('gyrA', 'nalA', 'parD', 'S ...

# %%
for entry in res:

      X[ (entry['organism'],entry['target_chembl_id'], entry['pref_name'],AA)   ]=None
    return X

# %%
# Function to retrieve targets associated with a ChEMBL ID
def get_targets(chembl_id):
    target_client = new_client.target
    # Retrieve targets associated with the ChEMBL ID
    res = target_client.filter(target=chembl_id).only(['target_chembl_id','organism','pref_name','target_components'])
    res = res[:100]
    # Extract the target ChEMBL IDs
    X=[]

    return {(entry['organism'],entry['target_chembl_id'], entry['pref_name']) for entry in res}



TOR1A = 'CHEMBL1829'  # Define the TOR1A target
get_targets(TOR1A)
# Out:
# {('Ascaris suum',
#   'CHEMBL1884',
#   'Nicotinic acetylcholine receptor alpha subunit'),
#  ('Candida albicans (strain SC5314 / ATCC MYA-2876) (Yeast)',
#   'CHEMBL1780',
#   'Cytochrome P450 51'),
#  ('Escherichia coli', 'CHEMBL1809', 'Dihydrofolate reductase'),
#  ('Escherichia coli', 'CHEMBL1826', 'DNA gyrase subunit B'),
#  ('Escherichia coli', 'CHEMBL2065', 'Beta-lactamase TEM'),
#  ('Escherichia coli K-12', 'CHEMBL1813', 'Penicillin-binding protein 1A'),
#  ('Escherichia coli K-12', 'CHEMBL1840', 'Penicillin-binding protein 2'),
#  ('Escherichia coli K-12',
#   'CHEMBL1852',
#   'DNA-directed RNA polymerase beta chain'),
#  ('Escherichia coli K-12',
#   'CHEMBL1857',
#   'Enoyl-[acyl-carrier-protein] reductase'),
#  ('Escherichia coli K-12', 'CHEMBL1858', 'DNA gyrase subunit A'),
#  ('Escherichia coli K-12', 'CHEMBL1956', 'D-alanylalanine synthetase'),
#  ('Escherichia coli K-12',
#   'CHEMBL1984',
#   'UDP-N-acetylglucosamine 1-carboxyvinyltransferase'),
#  ('Herpes simplex virus (type 1 / strain 17)',
#   'CHEMBL1872',
#   'Human herpesvirus 1 DNA polymerase'),
#  ('Homo sapiens', 'CHEMBL1781', 'DNA topoisomerase I'),
#  ('Homo sapiens', 'CHEMBL1782', 'Farnesyl diphosphate synthase'),
#  ('Homo sapiens', 'CHEMBL1786', 'Inositol-1(or 4)-monophosphatase 1'),
#  ('Homo sapiens', 'CHEMBL1787', 'Steroid 5-alpha-reductase 1'),
#  ('Homo sapiens', 'CHEMBL1790', 'Vasopressin V2 receptor'),
#  ('Homo sapiens', 'CHEMBL1801', 'Plasminogen'),
#  ('Homo sapiens', 'CHEMBL1806', 'DNA topoisomerase II alpha'),
#  ('Homo sapiens',
#   'CHEMBL1807',
#   'Sodium/potassium-transporting ATPase alpha-1 chain'),
#  ('Homo sapiens', 'CHEMBL1808', 'Angiotensin-converting enzyme'),
#  ('Homo sapiens', 'CHEMBL1812', 'Pancreatic lipase'),
#  ('Homo sapiens', 'CHEMBL1822', "Inosine-5'-monophosphate dehydrogenase 1"),
#  ('Homo sapiens', 'CHEMBL1827', 'Phosphodiesterase 5A'),
#  ('Homo sapiens', 'CHEMBL1828', 'DNA polymerase alpha subunit'),
#  ('Homo sapiens',
#   'CHEMBL1830',
#   'Ribonucleoside-diphosphate reductase M1 chain'),
#  ('Homo sapiens', 'CHEMBL1839', 'Thyroid peroxidase'),
#  ('Homo sapiens', 'CHEMBL1842', 'Myeloid cell surface antigen CD33'),
#  ('Homo sapiens', 'CHEMBL1843', 'DOPA decarboxylase'),
#  ('Homo sapiens', 'CHEMBL1846', 'Ryanodine receptor 1'),
#  ('Homo sapiens', 'CHEMBL1848', 'Tubulin beta-2 chain'),
#  ('Homo sapiens', 'CHEMBL1851', 'Cytochrome P450 7A1'),
#  ('Homo sapiens',
#   'CHEMBL1854',
#   'Luteinizing hormone/Choriogonadotropin receptor'),
#  ('Homo sapiens',
#   'CHEMBL1859',
#   'Voltage-gated T-type calcium channel alpha-1H subunit'),
#  ('Homo sapiens', 'CHEMBL1860', 'Thyroid hormone receptor alpha'),
#  ('Homo sapiens', 'CHEMBL1862', 'Tyrosine-protein kinase ABL'),
#  ('Homo sapiens', 'CHEMBL1867', 'Alpha-2a adrenergic receptor'),
#  ('Homo sapiens', 'CHEMBL1871', 'Androgen Receptor'),
#  ('Homo sapiens', 'CHEMBL1898', 'Serotonin 1b (5-HT1b) receptor'),
#  ('Homo sapiens', 'CHEMBL1902', 'FK506-binding protein 1A'),
#  ('Homo sapiens', 'CHEMBL1905', 'Fibronectin receptor beta'),
#  ('Homo sapiens', 'CHEMBL1908', 'Cytochrome P450 11B1'),
#  ('Homo sapiens', 'CHEMBL1910', 'Adenosine deaminase'),
#  ('Homo sapiens', 'CHEMBL1935', 'Aldehyde dehydrogenase'),
#  ('Homo sapiens', 'CHEMBL1941', 'Histamine H2 receptor'),
#  ('Homo sapiens', 'CHEMBL1950', 'Antithrombin-III'),
#  ('Homo sapiens', 'CHEMBL1951', 'Monoamine oxidase A'),
#  ('Homo sapiens', 'CHEMBL1952', 'Thymidylate synthase'),
#  ('Homo sapiens', 'CHEMBL1962', 'GABA receptor alpha-1 subunit'),
#  ('Homo sapiens', 'CHEMBL1963', 'Thyroid stimulating hormone receptor'),
#  ('Homo sapiens', 'CHEMBL1968', 'Epoxide hydrolase 1'),
#  ('Homo sapiens', 'CHEMBL1969', 'Tyrosine 3-hydroxylase'),
#  ('Homo sapiens', 'CHEMBL1970', 'Alcohol dehydrogenase alpha chain'),
#  ('Homo sapiens', 'CHEMBL1971', 'Sulfonylurea receptor 2'),
#  ('Homo sapiens', 'CHEMBL1973', 'Tyrosinase'),
#  ('Homo sapiens', 'CHEMBL1976', 'Growth hormone receptor'),
#  ('Homo sapiens', 'CHEMBL1977', 'Vitamin D receptor'),
#  ('Homo sapiens', 'CHEMBL1978', 'Cytochrome P450 19A1'),
#  ('Homo sapiens', 'CHEMBL1981', 'Insulin receptor'),
#  ('Homo sapiens', 'CHEMBL1983', 'Serotonin 1d (5-HT1d) receptor'),
#  ('Homo sapiens', 'CHEMBL1994', 'Mineralocorticoid receptor'),
#  ('Homo sapiens', 'CHEMBL2000', 'Plasma kallikrein'),
#  ('Homo sapiens', 'CHEMBL2002', "Inosine-5'-monophosphate dehydrogenase 2"),
#  ('Homo sapiens', 'CHEMBL202', 'Dihydrofolate reductase'),
#  ('Homo sapiens', 'CHEMBL2023', 'Catechol O-methyltransferase'),
#  ('Homo sapiens', 'CHEMBL2024', 'Follicle stimulating hormone receptor'),
#  ('Homo sapiens', 'CHEMBL203', 'Epidermal growth factor receptor erbB1'),
#  ('Homo sapiens', 'CHEMBL2033', 'Cytochrome P450 11A1'),
#  ('Homo sapiens', 'CHEMBL2034', 'Glucocorticoid receptor'),
#  ('Homo sapiens', 'CHEMBL2039', 'Monoamine oxidase B'),
#  ('Homo sapiens', 'CHEMBL204', 'Thrombin'),
#  ('Homo sapiens', 'CHEMBL205', 'Carbonic anhydrase II'),
#  ('Homo sapiens', 'CHEMBL2055', 'Retinoic acid receptor alpha'),
#  ('Homo sapiens', 'CHEMBL2056', 'Dopamine D1 receptor'),
#  ('Homo sapiens', 'CHEMBL206', 'Estrogen receptor alpha'),
#  ('Homo sapiens', 'CHEMBL2074', 'Maltase-glucoamylase'),
#  ('Homo sapiens', 'CHEMBL2075', 'Cyclophilin B'),
#  ('Homo sapiens', 'CHEMBL208', 'Progesterone receptor'),
#  ('Homo sapiens', 'CHEMBL209', 'Trypsin I'),
#  ('Homo sapiens', 'CHEMBL210', 'Beta-2 adrenergic receptor'),
#  ('Homo sapiens', 'CHEMBL211', 'Muscarinic acetylcholine receptor M2'),
#  ('Homo sapiens', 'CHEMBL212', 'Integrin alpha-IIb'),
#  ('Homo sapiens', 'CHEMBL213', 'Beta-1 adrenergic receptor'),
#  ('Homo sapiens', 'CHEMBL214', 'Serotonin 1a (5-HT1a) receptor'),
#  ('Homo sapiens', 'CHEMBL215', 'Arachidonate 5-lipoxygenase'),
#  ('Homo sapiens', 'CHEMBL216', 'Muscarinic acetylcholine receptor M1'),
#  ('Homo sapiens', 'CHEMBL217', 'Dopamine D2 receptor'),
#  ('Homo sapiens', 'CHEMBL218', 'Cannabinoid CB1 receptor'),
#  ('Homo sapiens', 'CHEMBL219', 'Dopamine D4 receptor'),
#  ('Homo sapiens', 'CHEMBL220', 'Acetylcholinesterase'),
#  ('Homo sapiens', 'CHEMBL221', 'Cyclooxygenase-1'),
#  ('Homo sapiens', 'CHEMBL222', 'Norepinephrine transporter'),
#  ('Homo sapiens', 'CHEMBL223', 'Alpha-1d adrenergic receptor'),
#  ('Homo sapiens', 'CHEMBL224', 'Serotonin 2a (5-HT2a) receptor'),
#  ('Homo sapiens', 'CHEMBL225', 'Serotonin 2c (5-HT2c) receptor'),
#  ('Homo sapiens', 'CHEMBL402', 'HMG-CoA reductase'),
#  ('Influenza A virus (A/Puerto Rico/8/1934(H1N1))',
#   'CHEMBL2051',
#   'Neuraminidase'),
#  ('Influenza A virus (A/Udorn/307/1972(H3N2))',
#   'CHEMBL2052',
#   'Influenza virus A matrix protein M2'),
#  ('Plasmodium falciparum K1', 'CHEMBL1939', 'Dihydrofolate reductase')}

# %% [markdown]
# https://hpo.jax.org/app/browse/disease/ORPHA:98807
#
# https://hpo.jax.org/app/browse/gene/1861

# %%
https://hpo.jax.org/app/browse/disease/ORPHA:98807

# %% [markdown]
# #####################################################################################
#
# Human Phenotype Ontology (HPO): Utilize the Human Phenotype Ontology, which provides standardized vocabulary for describing phenotypic abnormalities associated with human diseases. You can query the HPO to identify phenotypes specifically linked to DYT1 dystonia.
#
# Phenotypic Annotations: Retrieve phenotypic annotations associated with TOR1A (TorsinA) and the targets associated with the screening compounds from databases or literature sources. These annotations describe the phenotypic abnormalities observed in individuals with mutations or alterations in these genes.
#
# Comparison: Compare the phenotypic annotations of TOR1A with those of the targets associated with the screening compounds. Look for shared phenotypes that are specifically associated with DYT1 dystonia. Phenotypes such as "involuntary movements," "muscle spasms," "dystonia," and "motor dysfunction" may be relevant in this context.
#
# Relevance Assessment: Assess the relevance of the shared phenotypes to DYT1 dystonia. Phenotypes that are closely related to the clinical manifestations of the disease provide evidence of potential relevance of the targets to DYT1 dystonia.
#
# Prioritization: Prioritize the targets based on the extent of shared phenotypes with TOR1A and the severity of the associated phenotypic abnormalities. Targets showing a high degree of overlap with TOR1A and exhibiting clinically relevant phenotypes associated with DYT1 dystonia may represent promising candidates for further investigation.
#
# By integrating phenotypic comparisons using HPO annotations, we can enhance your understanding of the potential relevance of the identified targets to DYT1 dystonia and prioritize them for further experimental validation and drug discovery efforts. This approach strengthens the translational relevance of your findings and facilitates the identification of novel therapeutic targets for the disease.

# %%
from chembl_webresource_client.new_client import new_client

def perform_similarity_search(smiles, threshold=60):
    similarity = new_client.similarity
    # Perform similarity search using ChEMBL's similarity search API
    res = similarity.filter(smiles=smiles, similarity=threshold).only(['molecule_chembl_id', 'similarity'])
    similar_compounds = [(entry['molecule_chembl_id'],round(float(entry['similarity']),2)) for entry in res]
    similar_compounds_ = [entry['molecule_chembl_id'] for entry in res]
    return similar_compounds_

# Screening compounds with their IDs and SMILES strings
screening_compounds = {
    'NCGC00602080-03': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=C(F)C=CC=C4)N=C2C',
    'NCGC00685598-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC=CC=C4)N=C2C',
    'NCGC00685517-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC=CC(F)=C4)N=C2C',
    'NCGC00686269-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC(F)=CC(F)=C4)N=C2C'}

# Perform chemical structure similarity search against ChEMBL for each screening compound
similar_compounds_dict = {}
for compound_id, compound_smiles in screening_compounds.items():
    similar_compounds = perform_similarity_search(compound_smiles)
    print(similar_compounds)
    similar_compounds_dict[compound_id] = similar_compounds

similar_compounds_dict

from chembl_webresource_client.new_client import new_client

# Function to retrieve targets associated with a ChEMBL ID
def get_targets(chembl_id):
    target_client = new_client.target
    # Retrieve targets associated with the ChEMBL ID
    res = target_client.filter(target=chembl_id).only(['target_chembl_id','organism','pref_name'])
    res = res[:100]
    # Extract the target ChEMBL IDs
    return {(entry['organism'],entry['target_chembl_id'], entry['pref_name']) for entry in res}


# Function to find shared targets between two ChEMBL IDs
def find_shared_targets(chembl_id1, chembl_ids):
    # Retrieve targets associated with each ChEMBL ID
    targets1 = get_targets(chembl_id1)
    # Find the intersection of targets to get shared targets
    shared_targets = set()
    for chembl_id in chembl_ids:
        targets2 = get_targets(chembl_id)
        shared_targets.update(targets1.intersection(targets2))
    return shared_targets

# Get targets associated with ChEMBL compounds
chembl_targets = set()
for similar_compounds in similar_compounds_dict.values():
    chembl_targets.update(similar_compounds)

TOR1A = 'CHEMBL1829'  # Define the TOR1A target

# Find shared targets
shared_targets = find_shared_targets(TOR1A, chembl_targets)
print("Shared Targets:", list(shared_targets))  # Convert set to list for printing

# %%
import json
import pandas as pd

# Read the JSON file
file_path = '/content/hp.json'
with open(file_path, 'r') as file:
    data = json.load(file)
# Extract relevant information from the JSON dat
graphs = data['graphs']
nodes = graphs[0]['nodes']  # Assuming there's only one graph in the JSON data
# Initialize lists to store data
ids = []
labels = []
types = []
# Iterate over the nodes and extract the required information
for node in nodes:
    ids.append(node['id'])
    labels.append(node.get('lbl', ''))
    types.append(node.get('type', ''))
# Create a DataFrame from the extracted data
HP = pd.DataFrame({
    'id': ids,
    'label': labels,
    'type': types
})

import pandas as pd
phenotype_to_genes = pd.read_csv('/content/phenotype_to_genes.txt', sep='\t')
genes_to_phenotype = pd.read_csv('/content/genes_to_phenotype.txt', sep='\t')
genes_to_disease = pd.read_csv('/content/genes_to_disease.txt', sep='\t')
phenotype = pd.read_csv('/content/phenotype.hpoa', sep='\t', skiprows=4)
# Out:
# <ipython-input-41-781703eb0002>:31: DtypeWarning: Columns (2,6,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   phenotype = pd.read_csv('/content/phenotype.hpoa', sep='\t', skiprows=4)

# %%
Shared Targets:
('Homo sapiens', 'CHEMBL1843', 'DOPA decarboxylase', ('AADC', 'DDC', 'Synonyms=AADC’)),
 ('Escherichia coli', 'CHEMBL1809', 'Dihydrofolate reductase', ('folA', 'tmrA ‘)),
 ('Homo sapiens', 'CHEMBL1952', 'Thymidylate synthase', ('TS', 'TYMS’)),
 ('Homo sapiens', 'CHEMBL222', 'Norepinephrine transporter', ('NAT1', 'NET1', 'SLC6A2', 'SLC6A5’)),
 ('Homo sapiens', 'CHEMBL2033', 'Cytochrome P450 11A1', ('CYP11A', 'CYP11A1', 'Synonyms=CYP11A’)),
 ('Homo sapiens', 'CHEMBL211', 'Muscarinic acetylcholine receptor M2', ('CHRM2',)),
 ('Homo sapiens', 'CHEMBL1968', 'Epoxide hydrolase 1', ('EPHX', 'EPHX1', 'EPOX’)),
 And etc.

# %%
Shared_gene=[]
for i in list(shared_targets):
  Shared_gene+=list((i[3]))
Shared_gene=list(set(Shared_gene))
Shared_gene[:4]

# %%
Shared_hpo=[]
list_gene_symbol=list(genes_to_phenotype['gene_symbol'])
for i in Shared_gene:
  if i in list_gene_symbol:
     Shared_hpo.append(i)
Shared_hpo[:4]
# Out:
# ['FSHR', 'MAOA', 'TSHR', 'RYR1']

# %%
hpo_names=[]
for i in Shared_hpo:
    hpo_names+=list(genes_to_phenotype[genes_to_phenotype['gene_symbol']==i]['hpo_name'])
hpo_names=list(set(hpo_names))

# %%
hpo_names
# Out:
# ['Progressive gait ataxia',
#  'Reduced antithrombin antigen',
#  'Macroglossia',
#  'Desquamation of skin soon after birth',
#  'Motor delay',
#  'Functional abnormality of the bladder',
#  'Recurrent otitis media',
#  'Stomatitis',
#  'Adrenal hyperplasia',
#  'Lymphopenia',
#  'Male pseudohermaphroditism',
#  'Pectus carinatum',
#  'Furrowed tongue',
#  'Low-set ears',
#  'Left ventricular hypertrophy',
#  'Broad nasal tip',
#  'Fetal onset',
#  'Difficulty standing',
#  'Bloody diarrhea',
#  'Macrotia',
#  'Midface retrusion',
#  'Retinal pigment epithelial mottling',
#  'Tongue thrusting',
#  'Esodeviation',
#  'Waddling gait',
#  'Increased circulating interleukin 8 concentration',
#  'Hepatitis',
#  'Overfolded helix',
#  'Broad hallux',
#  'Respiratory distress',
#  'Pes valgus',
#  'Angioedema',
#  'Moon facies',
#  'Male hypogonadism',
#  'Wormian bones',
#  'Exertional dyspnea',
#  'Cirrhosis',
#  'Joint stiffness',
#  'Metaphyseal irregularity',
#  'Capillary leak',
#  'Deep philtrum',
#  'Skeletal muscle atrophy',
#  'Accelerated skeletal maturation',
#  'Nyctalopia',
#  'Limb muscle weakness',
#  'Increased circulating cortisol level',
#  'Intracranial hemorrhage',
#  'Abnormality of the skin',
#  'Bulbar signs',
#  'Hypocholesterolemia',
#  'Narrow face',
#  'Aplasia of the ovary',
#  'Thrombocytopenia',
#  'Rheumatoid arthritis',
#  'Broad hallux phalanx',
#  'Attenuation of retinal blood vessels',
#  'Poor wound healing',
#  'Abnormal periventricular white matter morphology',
#  'Right bundle branch block',
#  'Reduced radioactive iodine uptake',
#  'Nausea and vomiting',
#  'Vomiting',
#  'Omphalocele',
#  'Melanocytic nevus',
#  'Paresis of extensor muscles of the big toe',
#  'Impaired clot retraction',
#  'High hypermetropia',
#  'Short lower limbs',
#  'Decreased circulating T4 concentration',
#  'Caesarian section',
#  'Premature pubarche',
#  'Seizure',
#  'Migraine with aura',
#  'Short chin',
#  'Failure to thrive in infancy',
#  'Dystonia',
#  'Absent specific antibody response',
#  'Chronic myelogenous leukemia',
#  'Autosomal recessive inheritance',
#  'Abnormality of the urinary system',
#  'Photophobia',
#  'Reduced antithrombin III activity',
#  'Dyspnea',
#  'Abnormal circulating lipid concentration',
#  'Widely patent fontanelles and sutures',
#  'Rectal prolapse',
#  'Abnormality of the tonsils',
#  'Premature ovarian insufficiency',
#  'Porokeratosis',
#  'Nephritis',
#  'Abnormality of the foot musculature',
#  'Muscle weakness',
#  'Myopathic facies',
#  'Weak cry',
#  'Recurrent hypoglycemia',
#  'Bifid uvula',
#  'Heterotropia',
#  'Curly eyelashes',
#  'Acute hepatic failure',
#  'Hypokinesia',
#  'Infantile muscular hypotonia',
#  'Aplasia/Hypoplasia of the skin',
#  'Severe failure to thrive',
#  'Premature graying of hair',
#  'Low frustration tolerance',
#  'Platybasia',
#  'Abnormality of the abdominal wall',
#  'Impaired glucose tolerance',
#  'Albinism',
#  'Hypopigmentation of the skin',
#  'Proptosis',
#  'Acute hepatic steatosis',
#  'Nail dysplasia',
#  'Ph-positive acute lymphoblastic leukemia',
#  'Orthopnea',
#  'Hypohidrosis',
#  'Agenesis of corpus callosum',
#  'Megaloblastic anemia',
#  'Elevated urinary vanillylmandelic acid',
#  'Oral leukoplakia',
#  'Severe B lymphocytopenia',
#  'Abnormal circulating thyroglobulin concentration',
#  'Paranoia',
#  'Urethral diverticulum',
#  'Abnormality of the eye',
#  'Osteopenia',
#  'Narrow chest',
#  'Broad eyebrow',
#  'Abnormal morphology of female internal genitalia',
#  'Memory impairment',
#  'Increased circulating thyroglobulin concentration',
#  'Platelet anisocytosis',
#  'Sleep apnea',
#  'Ophthalmoplegia',
#  'Third trimester onset',
#  'Insulin-resistant diabetes mellitus',
#  'Neoplasm',
#  'Abdominal pain',
#  'Anemic pallor',
#  'Rickets',
#  'Lethargy',
#  'Kyphoscoliosis',
#  'Absent axillary hair',
#  'Abnormal lymphocyte morphology',
#  'Laryngeal edema',
#  'Multifocal epileptiform discharges',
#  'Autoimmune hemolytic anemia',
#  'Hypertriglyceridemia',
#  'Ventricular septal defect',
#  'Premature thelarche',
#  'Breech presentation',
#  'Polycystic ovaries',
#  'Abnormal cry',
#  'Broad first metatarsal',
#  'Persistence of primary teeth',
#  'Myoclonic absence seizure',
#  'Progressive flexion contractures',
#  'Hyporeflexia of upper limbs',
#  'Hallucinations',
#  'Lipoatrophy',
#  'High pitched voice',
#  'Azoospermia',
#  'Renotubular dysgenesis',
#  'Midshaft hypospadias',
#  'Narrow forehead',
#  'Thin vermilion border',
#  'Abnormality of blood and blood-forming tissues',
#  'Ventral shortening of foreskin',
#  'Macrovesicular hepatic steatosis',
#  'Striae distensae',
#  'Abnormal retinal morphology',
#  'Amenorrhea',
#  'Abnormal circulating C-peptide concentration',
#  'Delayed proximal femoral epiphyseal ossification',
#  'Congenital hypertrophy of left ventricle',
#  'Growth abnormality',
#  'Short long bone',
#  'Cryptorchidism',
#  'Weight loss',
#  'Hypertensive crisis',
#  'Nausea',
#  'Abnormal vagina morphology',
#  'Lower limb hyperreflexia',
#  'Abnormality of coagulation',
#  'Blue sclerae',
#  'Cataract',
#  'Clinodactyly of the 5th finger',
#  'Displacement of the urethral meatus',
#  'Focal aware seizure',
#  'Migraine without aura',
#  'Abnormal libido',
#  'Generalized tonic seizure',
#  'Decreased thyroid-stimulating hormone level',
#  'Renal insufficiency',
#  'Diarrhea',
#  'Glaucoma',
#  'Femoral bowing',
#  'Impaired arachidonic acid-induced platelet aggregation',
#  'Adrenal cortical sclerosis',
#  'Hyperventilation',
#  'Achilles tendon contracture',
#  'Congenital adrenal hyperplasia',
#  'Carious teeth',
#  'Metrorrhagia',
#  'Respiratory arrest',
#  'EMG: myopathic abnormalities',
#  'Abnormality of the ovary',
#  'Long nose',
#  'Meningocele',
#  'Exotropia',
#  'Secretory diarrhea',
#  'Exaggerated startle response',
#  'Cranial nerve compression',
#  'Gynecomastia',
#  'Generalized non-motor (absence) seizure',
#  'Abnormality of the middle ear',
#  'Enlarged tonsils',
#  'Corneal neovascularization',
#  'Hypercalciuria',
#  'EEG with generalized epileptiform discharges',
#  'Nail dystrophy',
#  'Generalized reticulate brown pigmentation',
#  'Fat malabsorption',
#  'Decreased serum insulin-like growth factor 1',
#  'Recurrent viral infections',
#  'Specific learning disability',
#  'High serum calcitriol',
#  'Areflexia of lower limbs',
#  'Enlarged polycystic ovaries',
#  'Joint contracture',
#  'Cervicitis',
#  'Abnormality of neuronal migration',
#  'Relative macrocephaly',
#  'Bone marrow hypercellularity',
#  'Pancreatic islet-cell hyperplasia',
#  'Abnormality of refraction',
#  'Attention deficit hyperactivity disorder',
#  'Intellectual disability',
#  'Skin-picking',
#  'Aplasia/Hypoplasia involving the nose',
#  'Hyponatremia',
#  'Encephalocele',
#  'Elevated systolic blood pressure',
#  'Cranial hyperostosis',
#  'Sparse bone trabeculae',
#  'Generalized edema',
#  'Paroxysmal ventricular tachycardia',
#  'Recurrent bacterial infections',
#  'Emotional lability',
#  'Downturned corners of mouth',
#  'Premature birth',
#  'Acute kidney injury',
#  'Autoimmune antibody positivity',
#  'Abnormal adipose tissue morphology',
#  'Hematuria',
#  'Spotty hypopigmentation',
#  'Horizontal eyebrow',
#  'Prolonged bleeding following procedure',
#  'Pulmonary arterial hypertension',
#  'Pes planus',
#  'Cognitive impairment',
#  'Recurrent bronchiolitis',
#  'Thickened skin',
#  'Hypoplastic ischiopubic ramus',
#  'Activating thyroid-stimulating hormone receptor defect',
#  'Superficial thrombophlebitis',
#  'Recurrent thromboembolism',
#  'Short toe',
#  'Thick vermilion border',
#  'Psychosis',
#  'Brachycephaly',
#  'Aganglionic megacolon',
#  'Reticular hyperpigmentation',
#  'Joint dislocation',
#  'Elevated serum acid phosphatase',
#  'Secondary hyperparathyroidism',
#  'Exercise-induced rhabdomyolysis',
#  'Giant platelets',
#  'Delayed cranial suture closure',
#  'Athetosis',
#  'Decreased eosinophil count',
#  'Increased serum testosterone level',
#  'Fasting hyperinsulinemia',
#  'Reduced subcutaneous adipose tissue',
#  'Cerebral calcification',
#  'Generalized bronze hyperpigmentation',
#  'Spinal cord compression',
#  'Laryngomalacia',
#  'Mixed respiratory and metabolic acidosis',
#  'Feeding difficulties',
#  'Retinal atrophy',
#  'Delayed ability to walk',
#  'Retinal vein occlusion',
#  'Testicular adrenal rest tumor',
#  'Kinetic tremor',
#  'Posterior subcapsular cataract',
#  'Diaphyseal sclerosis',
#  'Tetraparesis',
#  'Repeated pneumothoraces',
#  'Wide nose',
#  'Decreased circulating renin level',
#  'Chronic infection',
#  'Recurrent opportunistic infections',
#  'Shortened sleep phase',
#  'Tibial torsion',
#  'Plethora',
#  'Abnormal circulating vitamin A concentration',
#  'Elevated creatine kinase after exercise',
#  'Talipes',
#  'Dehydration',
#  'Anterior rib cupping',
#  'Congenital hip dislocation',
#  'Decreased testicular size',
#  'Elevated serum 11-deoxycortisol',
#  'Optic nerve compression',
#  'Large fontanelles',
#  'Abnormal form of the vertebral bodies',
#  'Babinski sign',
#  'Focal-onset seizure',
#  'Impaired ADP-induced platelet aggregation',
#  'Anal fissure',
#  'Downslanted palpebral fissures',
#  'Adrenogenital syndrome',
#  'Recurrent infantile hypoglycemia',
#  'Cafe-au-lait spot',
#  'Compulsive behaviors',
#  'Rigidity',
#  'Macroorchidism, postpubertal',
#  'Testicular neoplasm',
#  'Dandy-Walker malformation',
#  'High palate',
#  'Short distal phalanx of finger',
#  'Varicose veins',
#  'Chronic pulmonary obstruction',
#  'Thick hair',
#  'EEG with polyspike wave complexes',
#  'Neonatal onset',
#  'Short stature',
#  'Cardiomyocyte mitochondrial proliferation',
#  'Hydrops fetalis',
#  'Postprandial hyperglycemia',
#  'Anti-thyroid peroxidase antibody positivity',
#  'Hypernatriuria',
#  'Pneumonia',
#  'Hypoparathyroidism',
#  'Cardiorespiratory arrest',
#  'Syncope',
#  'Coronary artery atherosclerosis',
#  'Chronic diarrhea',
#  'Dyskinesia',
#  'Flat face',
#  'Overgrowth of external genitalia',
#  'Aplasia/Hypoplasia of the breasts',
#  'Alopecia universalis',
#  'Multiple rib fractures',
#  'Digenic inheritance',
#  'Pulmonary hypoplasia',
#  'Splenomegaly',
#  'Tendon xanthomatosis',
#  'Oliguria',
#  'Immunodeficiency',
#  'Myopia',
#  'Cutaneous photosensitivity',
#  'Frontal upsweep of hair',
#  'Nemaline bodies',
#  'Tooth agenesis',
#  'Recurrent thrombophlebitis',
#  'Limited neck range of motion',
#  'Supraventricular tachycardia',
#  'Abnormal circulating creatine kinase concentration',
#  'Rod-cone dystrophy',
#  'Impaired distal vibration sensation',
#  'Short palpebral fissure',
#  'Impulsivity',
#  'High forehead',
#  'Cleft palate',
#  'Decreased serum testosterone concentration',
#  'Multiple renal cysts',
#  'Freckling',
#  'Hypoplastic nasal bridge',
#  'Mask-like facies',
#  'Horizontal inferior border of scapula',
#  'Impaired collagen-related peptide-induced platelet aggregation',
#  'Marked delay in bone age',
#  'Abnormality of visual evoked potentials',
#  'Renal magnesium wasting',
#  'Tracheoesophageal fistula',
#  'Sporadic',
#  'Parkinsonism',
#  'Abnormal blood folate concentration',
#  'Prolonged prothrombin time',
#  'High-output congestive heart failure',
#  'Muscle spasm',
#  'Obsessive-compulsive trait',
#  'Delayed puberty',
#  'Type 1 and type 2 muscle fiber minicore regions',
#  'Heterochromia iridis',
#  'Increased urinary 11-deoxycorticosterone level',
#  'Optic atrophy',
#  'Elevated circulating catecholamine level',
#  'Acanthosis nigricans',
#  'Low hanging columella',
#  'Peripheral axonal neuropathy',
#  'Smooth philtrum',
#  'Secretory adrenocortical adenoma',
#  'Abnormal metaphysis morphology',
#  'Hyperkalemia',
#  'Abnormal pelvic girdle bone morphology',
#  'Blind vagina',
#  'Bulbous nose',
#  'Delayed epiphyseal ossification',
#  'Abnormality of movement',
#  'Global brain atrophy',
#  'Bicuspid aortic valve',
#  'Prominent forehead',
#  'Acute rhabdomyolysis',
#  'Dolichocephaly',
#  'Exercise intolerance',
#  'Geographic atrophy',
#  'Reduced tendon reflexes',
#  'Increased mean corpuscular volume',
#  'Increased body weight',
#  'Muscle fibrillation',
#  'Thyroid hyperplasia',
#  'Decreased body weight',
#  'Abnormality of the pharynx',
#  'Bradycardia',
#  'Focal impaired awareness seizure',
#  'Cardiomyopathy',
#  'Spina bifida',
#  'Hepatic steatosis',
#  'Increased circulating antimullerian hormone concentration',
#  'Nephrogenic diabetes insipidus',
#  'Abnormality of humoral immunity',
#  'B-cell lymphoma',
#  'Abnormal social behavior',
#  'Unilateral vocal cord paralysis',
#  'Exocrine pancreatic insufficiency',
#  'Hypophosphatemia',
#  'Periventricular white matter hyperintensities',
#  'Abnormal eyelash morphology',
#  'Abdominal mass',
#  'Ambiguous genitalia, female',
#  'Pulmonary embolism',
#  'Hyperlipidemia',
#  'Elevated circulating alkaline phosphatase concentration',
#  'Progressive muscle weakness',
#  'Insulin resistance',
#  'Recurrent gastroenteritis',
#  'Hypospadias',
#  'Decreased level of heparin co-factor II',
#  'Impaired collagen-induced platelet aggregation',
#  'Eunuchoid habitus',
#  'Enuresis nocturna',
#  'Cavernous hemangioma',
#  'Impaired thrombin-induced platelet aggregation',
#  'ST segment depression',
#  'Increased circulating prolactin concentration',
#  'Abnormal hip bone morphology',
#  'Limb undergrowth',
#  'Panic attack',
#  'Proximal amyotrophy',
#  'Pericardial effusion',
#  'Choanal atresia',
#  'Growth arrest lines',
#  'Cranial nerve paralysis',
#  'Small for gestational age',
#  'Polygenic inheritance',
#  'Hernia',
#  'Short nose',
#  'Excessive bleeding from superficial cuts',
#  'Hiatus hernia',
#  'Recurrent pancreatitis',
#  'Abnormality of thrombocytes',
#  'Thromboembolic stroke',
#  'Elevated circulating parathyroid hormone level',
#  'Renal salt wasting',
#  'Coronal craniosynostosis',
#  'Elevated tissue non-specific alkaline phosphatase',
#  'Cerebellar hypoplasia',
#  'Severe short stature',
#  'Facial palsy',
#  'Squamous cell carcinoma',
#  'Photosensitive myoclonic seizure',
#  'Focal dystonia',
#  'Aplasia of the thymus',
#  'Poor speech',
#  'Incisor macrodontia',
#  'Neoplasm of the nervous system',
#  'Increased circulating androstenedione concentration',
#  'Elevated circulating C-reactive protein concentration',
#  'Male sexual dysfunction',
#  'Abnormal fallopian tube morphology',
#  'Small earlobe',
#  'Large for gestational age',
#  'Intestinal malrotation',
#  'Adipose tissue loss',
#  'Thin bony cortex',
#  'Sandal gap',
#  'Renal potassium wasting',
#  'Intramuscular hematoma',
#  'Primary adrenal insufficiency',
#  'Difficulty climbing stairs',
#  'Blepharitis',
#  'Enlargement of the ankles',
#  'Congenital diaphragmatic hernia',
#  'Opsoclonus',
#  'Subcutaneous nodule',
#  'Posterior embryotoxon',
#  'Respiratory insufficiency due to muscle weakness',
#  'Muscle stiffness',
#  'Hand tremor',
#  'Abnormal cardiovascular system morphology',
#  'Status epilepticus without prominent motor symptoms',
#  'Disproportionate short-limb short stature',
#  'Severe intrauterine growth retardation',
#  'Hypopigmented skin patches',
#  'Mitral valve prolapse',
#  'Spinal myoclonus',
#  'Absence of secondary sex characteristics',
#  'Deeply set eye',
#  'Arrhinencephaly',
#  'Abnormal substantia nigra morphology',
#  'Breast aplasia',
#  'Pancreatic pseudocyst',
#  'Delayed skeletal maturation',
#  'Neonatal hyperbilirubinemia',
#  'Pathologic fracture',
#  'Facial edema',
#  'Hyporeflexia',
#  'Hypertrichosis',
#  'Dysarthria',
#  'Autosomal dominant inheritance',
#  'Elevated circulating insulin:C-peptide ratio',
#  'Induced vaginal delivery',
#  'Aggressive behavior',
#  'Crackles',
#  'Prolonged QT interval',
#  'Pedal edema',
#  'Anorexia',
#  'Allergy',
#  'Elevated circulating 17-hydroxyprogesterone concentration',
#  'Broad forehead',
#  'Necrotizing myopathy',
#  'Absence of pubertal development',
#  'Horizontal nystagmus',
#  'Proximal muscle weakness in upper limbs',
#  'Agitation',
#  'Osteoporosis',
#  'Adult onset',
#  'Temperature instability',
#  'EEG abnormality',
#  'Urethral stenosis',
#  'Jerky head movements',
#  'Incoordination',
#  'Cerebral hypoplasia',
#  'Ventricular fibrillation',
#  'Testicular atrophy',
#  'Intrauterine growth retardation',
#  'EEG with spike-wave complexes',
#  'Neonatal respiratory distress',
#  'EMG: decremental response of compound muscle action potential to repetitive nerve stimulation',
#  'Increased connective tissue',
#  'Intra-oral hyperpigmentation',
#  'EEG with spike-wave complexes (2.5-3.5 Hz)',
#  'Pancreatic calcification',
#  'Leukocytosis',
#  'Osteomalacia',
#  'Abnormal platelet count',
#  'Hypocalcemia',
#  'Undetectable light- and dark-adapted electroretinogram',
#  'Abnormal hair morphology',
#  'Fatigue',
#  'Suicidal ideation',
#  'Gait ataxia',
#  'Thin ribs',
#  'Vesicoureteral reflux',
#  'Autistic behavior',
#  'Pes cavus',
#  'Increased C-peptide level',
#  'Retinal degeneration',
#  'Periorbital ecchymosis with tarsal plate sparing',
#  'Postural tremor',
#  'Fibular bowing',
#  'Frog-leg posture',
#  'Hyperphosphatemia',
#  'Brisk reflexes',
#  'Distal amyotrophy',
#  'Positive perchlorate discharge test',
#  'Reduced leukocyte alkaline phosphatase',
#  'Neuroblastoma',
#  'Diabetes mellitus',
#  'Atrial fibrillation',
#  'Melanoma',
#  'Abnormal eyelid morphology',
#  'Small face',
#  'Abnormal respiratory system physiology',
#  'Clitoral hypertrophy',
#  'Abnormality of the genitourinary system',
#  'Primary amenorrhea',
#  'Areflexia',
#  'Microscopic hematuria',
#  'Anxiety',
#  'Wide mouth',
#  'Gastroesophageal reflux',
#  'Slow-growing scalp hair',
#  'Nephrolithiasis',
#  'Adrenocorticotropic hormone excess',
#  'Personality disorder',
#  'Aortic root aneurysm',
#  'Nephrotic syndrome',
#  'Failure to thrive',
#  'Increased body mass index',
#  'Fused labia majora',
#  'Dysphonia',
#  'Recurrent patellar dislocation',
#  'Aplastic/hypoplastic toenail',
#  'Sternocleidomastoid amyotrophy',
#  'Spina bifida occulta',
#  'Congenital hypothyroidism',
#  'Macroscopic hematuria',
#  'Sparse scalp hair',
#  'Metabolic acidosis',
#  'Bruising susceptibility',
#  'Recurrent fungal infections',
#  'Abnormal circulating cholesterol concentration',
#  'Depressed nasal bridge',
#  'Impaired ristocetin-induced platelet aggregation',
#  'Punding',
#  'Lymphedema',
#  'Cardiac arrest',
#  'EMG abnormality',
#  'ST segment elevation',
#  'Exercise-induced myalgia',
#  'Adrenal hypoplasia',
#  'Abnormal skull morphology',
#  'Peripapillary atrophy',
#  'Choreoathetosis',
#  'Sparse axillary hair',
#  'Ventricular arrhythmia',
#  'Prolonged bleeding time',
#  'Irritability',
#  'Aplasia/hypoplasia of the uterus',
#  'Avascular necrosis',
#  'Abdominal obesity',
#  'Mandibular prognathia',
#  'Breast hypoplasia',
#  'Bone cyst',
#  'Multiple prenatal fractures',
#  'Atopic dermatitis',
#  'Decreased CSF 5-methyltetrahydrofolate concentration',
#  'Strabismus',
#  'Nephrocalcinosis',
#  'Hypotension',
#  'Abnormal dental enamel morphology',
#  'Erlenmeyer flask deformity of the femurs',
#  'Rhabdomyolysis',
#  'Perianal dermatitis',
#  'Abnormal thrombosis',
#  'Webbed neck',
#  'Hemiplegia/hemiparesis',
#  'Scoliosis',
#  'Thick eyebrow',
#  'Oral cavity bleeding',
#  'Dental crowding',
#  'Hyperparathyroidism',
#  'Anal atresia',
#  'Macroorchidism',
#  'Prominence of the zygomatic bone',
#  'Overgrowth',
#  'Hypocalcemic seizures',
#  'Periodic hypokalemic paresis',
#  'Tibial bowing',
#  'Hyperlordosis',
#  'Edema',
#  'Generalized myoclonic seizure',
#  'Internally nucleated skeletal muscle fibers',
#  'Hypertrophic cardiomyopathy',
#  'Precocious puberty in males',
#  'Esophageal stenosis',
#  'Abnormal fingernail morphology',
#  'Conjunctivitis',
#  'Adrenal insufficiency',
#  'Depressed nasal ridge',
#  'Abnormality of retinal pigmentation',
#  'Acidosis',
#  'Decreased calvarial ossification',
#  'Telecanthus',
#  'Epileptic encephalopathy',
#  'Hypoplasia of the maxilla',
#  'Urinary incontinence',
#  'Short attention span',
#  'EEG with photoparoxysmal response',
#  'Increased radioactive iodine uptake',
#  'Abdominal wall muscle weakness',
#  'Impaired T cell function',
#  'Prematurely aged appearance',
#  'Axial hypotonia',
#  'Sinusitis',
#  'Arterial thrombosis',
#  'Bone pain',
#  'Apnea',
#  'Difficulty walking',
#  'Tibialis anterior muscle atrophy',
#  'Recurrent pneumonia',
#  'Cholelithiasis',
#  'Sensorineural hearing impairment',
#  'Limb dystonia',
#  'Blue irides',
#  'Severe global developmental delay',
#  'Postural instability',
#  'Melena',
#  'Hypopigmentation of hair',
#  'Negativism',
#  'Retinopathy',
#  'White forelock',
#  'Deep plantar creases',
#  'Long philtrum',
#  'Tetany',
#  'Hypoglycemic seizures',
#  'Malabsorption',
#  'Schizophrenia',
#  'Hypoglycemia',
#  'Broad-based gait',
#  'Coma',
#  'Fasciculations',
#  'Hypokalemia',
#  'Foot dorsiflexor weakness',
#  'Decreased circulating IgG level',
#  'Weakness of facial musculature',
#  'Elfin facies',
#  'Thick lower lip vermilion',
#  'Bronchoconstriction',
#  'Obesity',
#  'Upslanted palpebral fissure',
#  'Talipes equinovarus',
#  'Hydrocephalus',
#  'Gowers sign',
#  'Recurrent respiratory infections',
#  'Cuboid-shaped vertebral bodies',
#  'Stroke',
#  'Horner syndrome',
#  'Enlarged kidney',
#  'Distal muscle weakness',
#  'Typified by somatic mosaicism',
#  'Late onset',
#  'Poor appetite',
#  'Abnormality of metabolism/homeostasis',
#  'Delayed menarche',
#  'Hypogonadotropic hypogonadism',
#  'Short hallux',
#  'Low self-esteem',
#  'Abnormality of the endocrine system',
#  'Paroxysmal atrial fibrillation',
#  'Thromboembolism',
#  'Increased T3/T4 ratio',
#  'Nasal congestion',
#  'Migraine',
#  'Intermittent painful muscle spasms',
#  'Basal ganglia calcification',
#  'Onychogryposis',
#  'Increased circulating lactate dehydrogenase concentration',
#  'Diabetes insipidus',
#  'Epistaxis',
#  'Flat occiput',
#  'Left ventricular systolic dysfunction',
#  'Retinal arteriolar tortuosity',
#  'Anti-thyroglobulin antibody positivity',
#  'Ptosis',
#  'Lymphoma',
#  'Bifid scrotum',
#  'Central core regions in muscle fibers',
#  'Onychauxis',
#  'Premature loss of primary teeth',
#  'Hydroureter',
#  'Corneal arcus',
#  'Lactic acidosis',
#  'Dentinogenesis imperfecta',
#  'Constipation',
#  'Hearing impairment',
#  'Scaling skin',
#  'Sparse hair',
#  'Abnormality of the respiratory system',
#  'Infantile axial hypotonia',
#  'Atelectasis',
#  'Unexplained fevers',
#  'Muscular dystrophy',
#  'Bulging epiphyses',
#  'Pelvic girdle muscle weakness',
#  'Status epilepticus',
#  'Reduced red cell adenosine deaminase level',
#  'Pulmonary insufficiency',
#  'Splanchnic vein thrombosis',
#  'CNS demyelination',
#  'Cutaneous amyloidosis',
#  'Streak ovary',
#  'Hypergonadotropic hypogonadism',
#  'Abnormal heart valve morphology',
#  'Thickened calvaria',
#  'Esophagitis',
#  'Umbilical hernia',
#  'Gastrointestinal hemorrhage',
#  'Telangiectasia of the skin',
#  'Hypertelorism',
#  'Erythema',
#  'Atonic seizure',
#  'Growth delay',
#  'Elliptocytosis',
#  'Anorectal anomaly',
#  'Frontal balding',
#  'Venous thrombosis',
#  'Sepsis',
#  'Recurrent cutaneous fungal infections',
#  'Obstructive sleep apnea',
#  'Myalgia',
#  'Steppage gait',
#  'Generalized-onset seizure',
#  'Exercise-induced muscle cramps',
#  'Hirsutism',
#  'Chronic monilial nail infection',
#  'Ankle flexion contracture',
#  'Reduced bone mineral density',
#  'Chapped lip',
#  'Androgen insufficiency',
#  'Neonatal asphyxia',
#  'Non-small cell lung carcinoma',
#  'Hip dislocation',
#  'Abnormal pulse pressure',
#  'Genu valgum',
#  'Thyrotoxicosis with diffuse goiter',
#  'Hypovolemia',
#  'Dental malocclusion',
#  'Urogenital sinus anomaly',
#  'Generalized hirsutism',
#  'Abnormal lung lobation',
#  'Poor fine motor coordination',
#  'Atypical behavior',
#  'Abnormality of the pubic hair',
#  'Long face',
#  'Platyspondyly',
#  'Pulmonary artery stenosis',
#  'Menorrhagia',
#  'Polycystic kidney dysplasia',
#  'Sacral dimple',
#  'Miscarriage',
#  'Decreased fetal movement',
#  'Pectus excavatum',
#  'Joint hemorrhage',
#  'Hypernatremic dehydration',
#  'Abnormal facial shape',
#  'Abnormality of extrapyramidal motor function',
#  'Action tremor',
#  'Pruritus',
#  'Poor head control',
#  'Isosexual precocious puberty',
#  'Congenital onset',
#  'Iris hypopigmentation',
#  'Self-biting',
#  'Ocular albinism',
#  'Decreased circulating cortisol level',
#  'Ovoid vertebral bodies',
#  'Hypercapnia',
#  'Facial tics',
#  'Night sweats',
#  'Abnormal palmar dermatoglyphics',
#  'Lung adenocarcinoma',
#  'Abnormality of the kidney',
#  'Ventouse delivery',
#  'Abnormal optic disc morphology',
#  'Decreased liver function',
#  'Abnormality of masseter muscle',
#  'Slowly progressive',
#  'Scapular winging',
#  'Thrombocytosis',
#  'Aplasia/Hypoplasia of the cerebellar vermis',
#  'Hepatic vein thrombosis',
#  'Abnormal circulating renin',
#  'Delayed eruption of teeth',
#  'Juvenile onset',
#  'Anemia',
#  'Depression',
#  'Hyperactivity',
#  'Hypoplasia of the fovea',
#  'Hyposthenuria',
#  'Respiratory insufficiency',
#  'Squamous cell carcinoma of the skin',
#  'Bowing of the legs',
#  'Aplasia/Hypoplasia of the fallopian tube',
#  'Thoracic kyphosis',
#  'Hyperreflexia',
#  'Congestive heart failure',
#  'Impaired platelet aggregation',
#  'Potter facies',
#  'Germ cell neoplasia',
#  'Pointed chin',
#  'Episodic abdominal pain',
#  'Hyperkeratosis',
#  'Metabolic alkalosis',
#  'Orthostatic tachycardia',
#  'Abnormality of eye movement',
#  'Truncus arteriosus',
#  'Acne',
#  'Gingival overgrowth',
#  'Pyloric stenosis',
#  'Pustule',
#  "Writer's cramp",
#  'Colitis',
#  'Epilepsia partialis continua',
#  'Vertebral compression fracture',
#  'Hyperaldosteronism',
#  'Abnormal circulating hormone concentration',
#  'Spasticity',
#  'Bone marrow hypocellularity',
#  'Abnormal circulating testosterone concentration',
#  'Decreased platelet glycoprotein IIb-IIIa',
#  'Prostate cancer',
#  'Hypertonic dehydration',
#  'Decreased circulating IgG2 level',
#  'Progressive night blindness',
#  'Proximal muscle weakness',
#  'Absent skin pigmentation',
#  'Oculogyric crisis',
#  'Cutis marmorata',
#  'Elevated circulating luteinizing hormone level',
#  'Hypotelorism',
#  'Headache',
#  'Lymphadenopathy',
#  'Psoriasiform dermatitis',
#  'Dysphagia',
#  'Diffuse mesangial sclerosis',
#  'Cerebral palsy',
#  'Widely-spaced maxillary central incisors',
#  'Breast carcinoma',
#  'Absent tonsils',
#  'Severely reduced visual acuity',
#  'Short telomere length',
#  'Menometrorrhagia',
#  'Hypodontia',
#  'Minicore myopathy',
#  'Excessive salivation',
#  'Thyroid defect in oxidation and organification of iodide',
#  'Abnormal T-wave',
#  'Conductive hearing impairment',
#  'Abnormal blistering of the skin',
#  'Increased circulating IgE level',
#  'Photosensitive tonic-clonic seizure',
#  'Alveolar cell carcinoma',
#  'Recurrent upper respiratory tract infections',
#  'Type 1 muscle fiber atrophy',
#  'Bowing of limbs due to multiple fractures',
#  'Gingival bleeding',
#  'Increased urinary cortisol level',
#  'Typical absence seizure',
#  'Middle age onset',
#  'Pleural effusion',
#  'Increased circulating osteocalcin level',
#  'Secondary amenorrhea',
#  'Long foot',
#  'Abnormal sex determination',
#  'Dilated cardiomyopathy',
#  'Addictive alcohol use',
#  'Abdominal distention',
#  'Fever',
#  'Abnormal skeletal muscle morphology',
#  'Collectionism',
#  'Taurodontia',
#  'Bilateral ptosis',
#  'Cerebral atrophy',
#  'Abnormal circulating follicle-stimulating hormone concentration',
#  'Anhidrosis',
#  'Tented upper lip vermilion',
#  'Jaundice',
#  'Perineal hypospadias',
#  'Prolonged bleeding following circumcision',
#  'Hyperactive renin-angiotensin system',
#  'Generalized clonic seizure',
#  'Prominent nipples',
#  'Petechiae',
#  'Decreased CSF 5-hydroxyindolacetic acid concentration',
#  'Scaphocephaly',
#  'Esophageal atresia',
#  'Psychotic episodes',
#  'Polyuria',
#  'Infertility',
#  'Deformed rib cage',
#  'Abnormal optic nerve morphology',
#  'Sinus tachycardia',
#  'Focal hemiclonic seizure',
#  'Multiple suture craniosynostosis',
#  'Developmental regression',
#  'Congenital, generalized hypertrichosis',
#  'Blepharospasm',
#  'Reduced blood urea nitrogen',
#  'Ataxia',
#  'Underdeveloped supraorbital ridges',
#  'Female external genitalia in individual with 46,XY karyotype',
#  'Recurrent fever',
#  'Feeding difficulties in infancy',
#  'Skin vesicle',
#  'Seborrheic dermatitis',
#  ...]

# %%
genes_to_phenotype[genes_to_phenotype['gene_symbol']=='FSHR']#'TOR1A']

#'Homo sapiens', 'CHEMBL217', 'Dopamine D2 receptor'
# Out:
#        ncbi_gene_id gene_symbol      hpo_id  \
# 52515          2492        FSHR  HP:0001166
# 52516          2492        FSHR  HP:0009888
# 52517          2492        FSHR  HP:0001251
# 52518          2492        FSHR  HP:0007430
# 52519          2492        FSHR  HP:0008684
# 52520          2492        FSHR  HP:0008675
# 52521          2492        FSHR  HP:0000062
# 52522          2492        FSHR  HP:0000007
# 52523          2492        FSHR  HP:0000006
# 52524          2492        FSHR  HP:0000144
# 52525          2492        FSHR  HP:0000138
# 52526          2492        FSHR  HP:0000119
# 52527          2492        FSHR  HP:0000133
# 52528          2492        FSHR  HP:0000133
# 52529          2492        FSHR  HP:0002750
# 52530          2492        FSHR  HP:0002018
# 52531          2492        FSHR  HP:0002018
# 52532          2492        FSHR  HP:0002017
# 52533          2492        FSHR  HP:0002027
# 52534          2492        FSHR  HP:0002027
# 52535          2492        FSHR  HP:0100598
# 52536          2492        FSHR  HP:0010464
# 52537          2492        FSHR  HP:0008209
# 52538          2492        FSHR  HP:0008214
# 52539          2492        FSHR  HP:0002225
# 52540          2492        FSHR  HP:0002202
# 52541          2492        FSHR  HP:0002206
# 52542          2492        FSHR  HP:0001007
# 52543          2492        FSHR  HP:0003621
# 52544          2492        FSHR  HP:0001939
# 52545          2492        FSHR  HP:0004322
# 52546          2492        FSHR  HP:0005625
# 52547          2492        FSHR  HP:0004349
# 52548          2492        FSHR  HP:0000786
# 52549          2492        FSHR  HP:0000786
# 52550          2492        FSHR  HP:0000869
# 52551          2492        FSHR  HP:0000837
# 52552          2492        FSHR  HP:0000837
# 52553          2492        FSHR  HP:0000837
# 52554          2492        FSHR  HP:0000823
# 52555          2492        FSHR  HP:0012886
# 52556          2492        FSHR  HP:0003270
# 52557          2492        FSHR  HP:0010311
# 52558          2492        FSHR  HP:0000939
# 52559          2492        FSHR  HP:0000938
# 52560          2492        FSHR  HP:0030088
# 52561          2492        FSHR  HP:0000252
# 52562          2492        FSHR  HP:0030005
# 52563          2492        FSHR  HP:0001541
# 52564          2492        FSHR  HP:0001541
# 52565          2492        FSHR  HP:0012398
# 52566          2492        FSHR  HP:0000365
# 52567          2492        FSHR  HP:0011106
#
#                                        hpo_name   frequency   disease_id
# 52515                            Arachnodactyly  HP:0040284    ORPHA:243
# 52516      Abnormality of secondary sexual hair  HP:0040281    ORPHA:243
# 52517                                    Ataxia  HP:0040284    ORPHA:243
# 52518                         Generalized edema  HP:0040283  ORPHA:64739
# 52519          Aplasia/hypoplasia of the uterus  HP:0040282    ORPHA:243
# 52520               Enlarged polycystic ovaries  HP:0040281  ORPHA:64739
# 52521                       Ambiguous genitalia  HP:0040285    ORPHA:243
# 52522           Autosomal recessive inheritance           -  OMIM:233300
# 52523            Autosomal dominant inheritance           -  OMIM:608115
# 52524                       Decreased fertility  HP:0040281    ORPHA:243
# 52525                              Ovarian cyst  HP:0040282  ORPHA:64739
# 52526   Abnormality of the genitourinary system           -  OMIM:608115
# 52527                        Gonadal dysgenesis  HP:0040280    ORPHA:243
# 52528                        Gonadal dysgenesis           -  OMIM:233300
# 52529               Delayed skeletal maturation  HP:0040282    ORPHA:243
# 52530                                    Nausea           -  OMIM:608115
# 52531                                    Nausea  HP:0040281  ORPHA:64739
# 52532                       Nausea and vomiting  HP:0040281  ORPHA:64739
# 52533                            Abdominal pain           -  OMIM:608115
# 52534                            Abdominal pain  HP:0040281  ORPHA:64739
# 52535                           Pulmonary edema  HP:0040283  ORPHA:64739
# 52536                              Streak ovary  HP:0040282    ORPHA:243
# 52537           Premature ovarian insufficiency  HP:0040280    ORPHA:243
# 52538                 Decreased serum estradiol  HP:0040281    ORPHA:243
# 52539                         Sparse pubic hair  HP:0040282    ORPHA:243
# 52540                          Pleural effusion  HP:0040282  ORPHA:64739
# 52541                        Pulmonary fibrosis  HP:0040284    ORPHA:243
# 52542                                 Hirsutism  HP:0040281  ORPHA:64739
# 52543                            Juvenile onset           -  OMIM:233300
# 52544     Abnormality of metabolism/homeostasis  HP:0040283    ORPHA:243
# 52545                             Short stature  HP:0040283    ORPHA:243
# 52546                 Osteoporosis of vertebrae  HP:0040282    ORPHA:243
# 52547              Reduced bone mineral density  HP:0040282    ORPHA:243
# 52548                        Primary amenorrhea           -  OMIM:233300
# 52549                        Primary amenorrhea  HP:0040281    ORPHA:243
# 52550                      Secondary amenorrhea  HP:0040283    ORPHA:243
# 52551  Increased circulating gonadotropin level  HP:0040281  ORPHA:64739
# 52552  Increased circulating gonadotropin level  HP:0040281    ORPHA:243
# 52553  Increased circulating gonadotropin level           -  OMIM:233300
# 52554                           Delayed puberty  HP:0040281    ORPHA:243
# 52555                  Hemorrhagic ovarian cyst  HP:0040282  ORPHA:64739
# 52556                      Abdominal distention  HP:0040281  ORPHA:64739
# 52557         Aplasia/Hypoplasia of the breasts  HP:0040282    ORPHA:243
# 52558                              Osteoporosis           -  OMIM:233300
# 52559                                Osteopenia  HP:0040282    ORPHA:243
# 52560        Increased serum testosterone level  HP:0040281  ORPHA:64739
# 52561                              Microcephaly  HP:0040284    ORPHA:243
# 52562                            Capillary leak  HP:0040281  ORPHA:64739
# 52563                                   Ascites           -  OMIM:608115
# 52564                                   Ascites  HP:0040281  ORPHA:64739
# 52565                          Peripheral edema  HP:0040283  ORPHA:64739
# 52566                        Hearing impairment  HP:0040283    ORPHA:243
# 52567                               Hypovolemia  HP:0040283  ORPHA:64739

# %%
# !pip install biothings_client
# Out:
# Requirement already satisfied: biothings_client in /usr/local/lib/python3.10/dist-packages (0.3.1)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from biothings_client) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->biothings_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->biothings_client) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->biothings_client) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->biothings_client) (2024.2.2)

# %%
import requests

# Function to query Ensembl REST API to map target information to Ensembl ID
def map_target_to_ensembl(target_info):
    ensembl_id = None
    # Construct the Ensembl REST API URL
    url = f"https://rest.ensembl.org/lookup/id/{target_info}?content-type=application/json"
    # Send GET request to Ensembl REST API
    response = requests.get(url)
    # Check if request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        # Extract Ensembl ID
        if 'id' in data:
            ensembl_id = data['id']
    return ensembl_id

# Example target information (e.g., target_chembl_id, organism, pref_name)
target_info = 'CHEMBL1829'  # Example ChEMBL target ID
# Map target information to Ensembl ID
ensembl_id = map_target_to_ensembl(target_info)
print("Ensembl ID:", ensembl_id)
# Out:
# Ensembl ID: None

# %%
# !pip install biomart
from biomart import BiomartServer

# Function to query BioMart and map target information to Ensembl ID
def map_target_to_ensembl(target_info):
    ensembl_id = None
    # Connect to the BioMart server
    server = BiomartServer("http://www.ensembl.org/biomart")
    # Specify the dataset to use
    dataset = server.datasets['hsapiens_gene_ensembl']
    # Query BioMart for Ensembl ID based on the target information
    response = dataset.search({'filters': {'external_gene_name': target_info}, 'attributes': ['ensembl_gene_id']})
    # Extract Ensembl ID from the response
    for entry in response.iter_lines():
        entry = entry.decode('utf-8')
        ensembl_id = entry.split('\t')[0]
        break  # Break after the first entry
    return ensembl_id

# Example target information (e.g., target_chembl_id, organism, pref_name)   #'Alpha-1d adrenergic receptor'#'
target_info = 'TOR1A' # Example target information
# Map target information to Ensembl ID
ensembl_id = map_target_to_ensembl(target_info)
print("Ensembl ID:", ensembl_id)
# Out:
# Collecting biomart
#   Downloading biomart-0.9.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests>=2.2 in /usr/local/lib/python3.10/dist-packages (from biomart) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2->biomart) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2->biomart) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2->biomart) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2->biomart) (2024.2.2)
# Installing collected packages: biomart
# Successfully installed biomart-0.9.2
# Ensembl ID: ENSG00000136827

# %%
from biothings_client import get_client

# Function to retrieve phenotypic annotations from HPO
def get_phenotypic_annotations(ensembl_id):
    hpo_client = get_client('gene')
    # Query Human Phenotype Ontology for phenotypic annotations associated with the gene
    res = hpo_client.query(q=ensembl_id)
    if 'hits' in res and res['hits']:
        annotations = res['hits'][0].get('phenotype_related_to_gene', [])
        return set(annotation['id'] for annotation in annotations)
    else:
        return set()

# Function to compare phenotypic annotations and identify shared phenotypes
def find_shared_phenotypes(target_ensembl_id1, target_ensembl_ids):
    # Retrieve phenotypic annotations for the first target
    phenotypes1 = get_phenotypic_annotations(target_ensembl_id1)
    # Initialize a dictionary to store shared phenotypes count for each target
    shared_phenotypes_count = {target_ensembl_id: 0 for target_ensembl_id in target_ensembl_ids}
    # Find the intersection of phenotypic annotations to get shared phenotypes
    for target_ensembl_id in target_ensembl_ids:
        phenotypes2 = get_phenotypic_annotations(target_ensembl_id)
        shared_phenotypes = phenotypes1.intersection(phenotypes2)
        shared_phenotypes_count[target_ensembl_id] = len(shared_phenotypes)
    return shared_phenotypes_count


# Get Ensembl IDs associated with targets
ensembl_ids = ['ENSG00000164109', 'ENSG00000139618', 'ENSG00000204498']  # Example Ensembl IDs for targets

# Find shared phenotypes
shared_phenotypes = find_shared_phenotypes('ENSG00000164087', ensembl_ids)  # Example Ensembl ID for TOR1A
print("Shared Phenotypes:", shared_phenotypes)  # Print shared phenotypes
# Out:
# Shared Phenotypes: {'ENSG00000164109': 0, 'ENSG00000139618': 0, 'ENSG00000204498': 0}

# %% [markdown]
# We calculate the count of shared phenotypes between each target and TOR1A (ENSG00000164087) and store them in a dictionary shared_phenotypes_count.
#
# We define relevance scores for each target based on domain knowledge.
#
# We calculate a score for each target by multiplying the count of shared phenotypes by its relevance score.
#
# We sort the targets based on their scores in descending order to prioritize them. The higher the score, the higher the priority. You can adjust the relevance scores based on your understanding of the targets' importance to DYT1 dystonia.

# %%
# Find shared phenotypes count for each target
shared_phenotypes_count = find_shared_phenotypes('ENSG00000164087', ensembl_ids)  # Example Ensembl ID for TOR1A
print("Shared Phenotypes Count:", shared_phenotypes_count)  # Print shared phenotypes count


# Define relevance scores for each target (you can modify these scores based on domain knowledge)
relevance_scores = {
    'ENSG00000164109': 5,  # Example relevance score for target 1
    'ENSG00000139618': 3,  # Example relevance score for target 2
    'ENSG00000204498': 2   # Example relevance score for target 3
}

# Prioritize targets based on shared phenotypes count and relevance to DYT1 dystonia
target_scores = {ensembl_id: shared_phenotypes_count[ensembl_id] * relevance_scores[ensembl_id] for ensembl_id in ensembl_ids}
# Sort targets based on scores in descending order
sorted_targets = sorted(target_scores.items(), key=lambda x: x[1], reverse=True)
print("Sorted Targets (Ensembl ID, Score):", sorted_targets)  # Print sorted targets
# Out:
# Shared Phenotypes Count: {'ENSG00000164109': 0, 'ENSG00000139618': 0, 'ENSG00000204498': 0}
# Sorted Targets (Ensembl ID, Score): [('ENSG00000164109', 0), ('ENSG00000139618', 0), ('ENSG00000204498', 0)]

# %% [markdown]
# Here are some additional steps you can consider:
#
# Target Validation: Verify the relevance of the identified targets in the context of DYT1 dystonia. Are these targets known to be involved in the disease pathway? Are there any literature references supporting their role in DYT1 dystonia?
#
# Pathway Analysis: Investigate the biological pathways associated with the identified targets. Are there common pathways or biological processes shared among these targets? Are any of these pathways relevant to the pathogenesis of DYT1 dystonia?
#
# Structural Analysis: Examine the three-dimensional structures of the identified targets and the binding sites of the screening compounds. Are there structural features that suggest potential interactions between the compounds and the targets? Can computational docking studies be performed to predict binding affinities and modes of interaction?
#
# Functional Assays: Consider conducting functional assays to validate the effects of the screening compounds on the identified targets. This could include in vitro assays to assess protein activity, cellular assays to evaluate phenotypic changes, or animal models to study therapeutic efficacy in vivo.
#
# Lead Optimization: If promising compounds are identified, explore strategies for lead optimization to improve potency, selectivity, and pharmacokinetic properties. This could involve medicinal chemistry efforts to design analogs with improved drug-like properties.
#
# By integrating these additional analyses and experimental approaches, you can further elucidate the potential mechanisms of action of the screening compounds and advance towards the identification of novel therapeutic candidates for DYT1 dystonia.

# %% [markdown]
# # Pathway analysis
#
#  investigate the biological pathways associated with the identified targets, you can use pathway databases such as Reactome, KEGG, or WikiPathways. Below is an example of how you can perform pathway analysis using the Reactome database:

# %%
import requests

# Function to retrieve pathways associated with a given gene (Ensembl ID)
def get_pathways(ensembl_id):
    # Construct the URL for Reactome pathway analysis
    url = f"https://reactome.org/ContentService/data/pathways/low/entity/{ensembl_id}"
    # Send GET request to Reactome API
    response = requests.get(url)
    # Check if request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        # Extract pathway information
        pathways = [pathway['displayName'] for pathway in data]
        return pathways
    else:
        print("Error:", response.text)
        return []

# Example Ensembl IDs for shared targets (replace with your actual Ensembl IDs)
shared_target_ensembl_ids = ['ENSG00000164109', 'ENSG00000139618', 'ENSG00000204498']

# Dictionary to store pathways associated with each target
target_pathways = {}

# Retrieve pathways for each target
for ensembl_id in shared_target_ensembl_ids:
    pathways = get_pathways(ensembl_id)
    target_pathways[ensembl_id] = pathways
    print(f"Pathways associated with {ensembl_id}: {pathways}")

# Identify common pathways among the targets
common_pathways = set.intersection(*[set(pathways) for pathways in target_pathways.values()])

print("Common Pathways:", common_pathways)
# Out:
# Error: {"code":404,"reason":"NOT_FOUND","url":"http://reactome.org/ContentService/data/pathways/low/entity/ENSG00000164109","messages":["No result for ENSG00000164109 in null"],"targets":null}
# Pathways associated with ENSG00000164109: []
# Error: {"code":404,"reason":"NOT_FOUND","url":"http://reactome.org/ContentService/data/pathways/low/entity/ENSG00000139618","messages":["No result for ENSG00000139618 in null"],"targets":null}
# Pathways associated with ENSG00000139618: []
# Error: {"code":404,"reason":"NOT_FOUND","url":"http://reactome.org/ContentService/data/pathways/low/entity/ENSG00000204498","messages":["No result for ENSG00000204498 in null"],"targets":null}
# Pathways associated with ENSG00000204498: []
# Common Pathways: set()

# %%
import requests

# Function to retrieve pathways associated with a given gene (Ensembl ID)
def get_pathways(ensembl_id):
    # Construct the URL for KEGG pathway analysis
    url = f"http://rest.kegg.jp/link/pathway/{ensembl_id}"
    # Send GET request to KEGG API
    response = requests.get(url)
    # Check if request was successful (status code 200)
    if response.status_code == 200:
        # Parse the response
        pathways = set()
        for line in response.text.split('\n'):
            if line:
                fields = line.split('\t')
                pathway_id = fields[1].split(':')[-1]
                pathways.add(pathway_id)
        return pathways
    else:
        print(f"Error retrieving pathways for {ensembl_id}: {response.text}")
        return set()

# Example Ensembl IDs for shared targets (replace with your actual Ensembl IDs)
shared_target_ensembl_ids = ['ENSG00000164109', 'ENSG00000139618', 'ENSG00000204498']

# Dictionary to store pathways associated with each target
target_pathways = {}

# Retrieve pathways for each target
for ensembl_id in shared_target_ensembl_ids:
    pathways = get_pathways(ensembl_id)
    target_pathways[ensembl_id] = pathways
    print(f"Pathways associated with {ensembl_id}: {pathways}")

# Identify common pathways among the targets
common_pathways = set.intersection(*[set(pathways) for pathways in target_pathways.values()])

print("Common Pathways:", common_pathways)
# Out:
# Error retrieving pathways for ENSG00000164109:
# Pathways associated with ENSG00000164109: set()
# Error retrieving pathways for ENSG00000139618:
# Pathways associated with ENSG00000139618: set()
# Error retrieving pathways for ENSG00000204498:
# Pathways associated with ENSG00000204498: set()
# Common Pathways: set()

# %% [markdown]
# # structural analysis
#
# To perform structural analysis and examine the three-dimensional structures of the identified targets and the binding sites of the screening compounds, you would typically follow these steps:
#
# Retrieve protein structures: Obtain the three-dimensional structures of the identified targets from databases such as the Protein Data Bank (PDB) or from homology modeling tools.
#
# Analyze binding sites: Identify the binding sites or active sites of the target proteins where the screening compounds are likely to interact. This can be done by analyzing the protein structures or using computational tools for binding site prediction.
#
# Docking studies: Perform computational docking studies to predict the binding affinities and modes of interaction between the screening compounds and the target proteins. This involves simulating the binding of the compounds to the protein structures and predicting the most energetically favorable binding conformations.
#
# Here's a general outline of how you can implement these steps using Python and relevant libraries:
#
# Retrieve protein structures:
#
# You can use libraries like Biopython to fetch protein structures from the Protein Data Bank (PDB) or use tools like SWISS-MODEL for homology modeling if the structure is not available.
# Analyze binding sites:
#
# Use tools like PyMOL or ChimeraX to visualize the protein structures and identify the binding sites.
# Alternatively, use computational tools like SiteMap or fpocket for automated binding site prediction.
# Docking studies:
#
# Utilize molecular docking software such as AutoDock, AutoDock Vina, or GOLD for performing docking studies.
# Prepare the ligand (screening compound) structures and protein structures for docking using appropriate file formats.
# Perform docking simulations to predict the binding affinities and modes of interaction between the compounds and the protein targets.
# Analyze the docking results to identify potential interactions and prioritize compounds for further experimental validation.

# %%
# Example code for structural analysis and docking studies

# Step 1: Retrieve protein structures (example using Biopython)
from Bio.PDB import PDBList

# Function to download PDB file for a given PDB ID
def download_pdb(pdb_id):
    pdb_list = PDBList()
    pdb_list.retrieve_pdb_file(pdb_id, file_format="pdb", pdir=".")

# Example usage:
download_pdb("1abc")  # Replace "1abc" with the actual PDB ID of the protein

# Step 2: Analyze binding sites (manual or using computational tools)
# Visualization of protein structures and binding sites can be done using PyMOL, ChimeraX, etc.

# Step 3: Docking studies (using molecular docking software)
# Example: perform docking using AutoDock Vina (assuming you have the software installed)
# You would typically prepare ligand and protein structures and run docking simulations
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-2dd68e49f2a0> in <cell line: 4>()
#       2
#       3 # Step 1: Retrieve protein structures (example using Biopython)
# ----> 4 from Bio.PDB import PDBList
#       5
#       6 # Function to download PDB file for a given PDB ID
#
# ModuleNotFoundError: No module named 'Bio'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
#  # functional assays
#
#  To conduct functional assays to validate the effects of the screening compounds on the identified targets, you would typically follow these steps:
#
# Selection of Assay: Choose appropriate functional assays based on the targets and compounds of interest. This could include in vitro assays to assess protein activity, cellular assays to evaluate phenotypic changes, or animal models to study therapeutic efficacy in vivo.
#
# Assay Development: Develop or acquire the necessary reagents, cell lines, and protocols for conducting the chosen assays. Optimize assay conditions to ensure robust and reproducible results.
#
# Compound Testing: Perform the functional assays using the screening compounds to evaluate their effects on the targets. This involves treating cells or animals with the compounds and measuring relevant endpoints, such as protein activity, phenotypic changes, or therapeutic outcomes.
#
# Data Analysis: Analyze the assay results to assess the impact of the compounds on the targets. Compare the effects of the compounds to appropriate controls and quantify the observed changes.
#
# Validation and Follow-Up: Validate the assay results through replication and additional experiments, if necessary. Follow up on promising findings with further investigation or optimization.

# %%
# Example code for conducting functional assays

# Step 1: Select appropriate assays based on targets and compounds of interest

# Step 2: Develop or acquire assay protocols and reagents

# Step 3: Perform functional assays
# Example: Conduct cellular assays using appropriate cell lines and endpoints
# Example code for a hypothetical cellular assay using a cell viability endpoint:

def perform_cellular_assay(compound_id, cell_line):
    # Treat cells with the screening compound
    # Incubate cells under appropriate conditions
    # Measure cell viability using a suitable assay (e.g., MTT assay, cell counting)
    # Compare viability of treated cells to untreated controls
    # Analyze assay results

# Perform cellular assays for each compound and target combination
for compound_id, compound_info in similar_compounds_dict.items():
    for target in shared_targets:
        cell_line = "CHO-K1"  # Example cell line
        assay_results = perform_cellular_assay(compound_id, cell_line)
        print(f"Assay results for compound {compound_id} on target {target}: {assay_results}")

# Step 4: Analyze assay results
# Example: Calculate cell viability percentages and compare to controls

# Step 5: Validate and follow up on promising findings
# Example: Confirm results with replicate experiments or additional assays

# %% [markdown]
#  #lead optimization strategies, you would typically follow these steps:
#
# Identify Promising Compounds: Based on the results of screening and target identification, select the most promising compounds for lead optimization. These compounds should exhibit desirable activity against the target and have the potential for further improvement.
#
# Analyze Structure-Activity Relationship (SAR): Investigate the structure-activity relationship of the selected compounds to understand how changes in chemical structure affect biological activity. Identify key structural features responsible for activity and explore modifications to enhance potency, selectivity, and other drug-like properties.
#
# Medicinal Chemistry Design: Employ medicinal chemistry principles to design analogs or derivatives of the lead compounds with improved properties. This could involve modifying functional groups, altering stereochemistry, or optimizing physicochemical properties to enhance drug-likeness.
#
# Synthesis and Testing: Synthesize the designed compounds and test them in relevant assays to evaluate their activity, selectivity, and pharmacokinetic properties. Iteratively refine compound designs based on assay results and SAR analysis.
#
# Iterative Optimization: Continuously iterate through the design, synthesis, and testing cycle to refine lead compounds further. Prioritize compounds that demonstrate superior activity, selectivity, and pharmacokinetic profiles for further optimization.
#
# Lead Candidate Selection: Identify lead candidates with optimal properties for preclinical development. Conduct comprehensive characterization and profiling of lead compounds to assess their potential as drug candidates.
#
# Preclinical Evaluation: Evaluate lead candidates in preclinical studies to assess safety, efficacy, and pharmacokinetics in relevant disease models. Select lead candidates with the best overall profile for advancement into clinical development.

# %%
# Example code for lead optimization

# Step 1: Identify promising compounds for lead optimization
promising_compounds = []  # Placeholder for selected compounds

# Step 2: Analyze structure-activity relationship (SAR)
# Perform SAR analysis to identify key structural features related to activity

# Step 3: Medicinal chemistry design
# Design analogs or derivatives of lead compounds with improved properties
# Example: Modify functional groups, optimize physicochemical properties

# Step 4: Synthesis and testing
# Synthesize designed compounds and test them in relevant assays
# Example: Assess activity, selectivity, and pharmacokinetic properties

# Step 5: Iterative optimization
# Refine compound designs based on assay results and SAR analysis
# Example: Iteratively modify compounds and retest them in assays

# Step 6: Lead candidate selection
# Prioritize compounds with optimal properties for preclinical development
# Example: Comprehensive characterization and profiling of lead candidates

# Step 7: Preclinical evaluation
# Evaluate lead candidates in preclinical studies to assess safety, efficacy, and pharmacokinetics
# Example: Conduct in vivo studies in relevant disease models

# Additional considerations:
# - Collaborate with medicinal chemists and computational chemists for compound design and optimization
# - Utilize computational tools for structure-based drug design, virtual screening, and molecular modeling
# - Employ predictive models and machine learning algorithms to guide compound optimization

# %% [markdown]
# # Ientify novel therapeutic candidates for DYT1 dystonia
#
# Retrieve Known Compounds: Use ChEMBL to retrieve known compounds with activity against relevant targets associated with DYT1 dystonia.
#
# Perform Similarity Search: Conduct a chemical similarity search using the retrieved compounds as queries. This search will identify compounds with similar chemical structures to known active compounds.
#
# Evaluate Similar Compounds: Assess the similarity search results to identify novel compounds that are structurally similar to known active compounds but may not yet be associated with DYT1 dystonia.
#
# Prioritize Compounds: Prioritize the identified compounds based on various factors such as predicted activity, drug-likeness, and availability for further experimental validation.

# %%
from chembl_webresource_client.new_client import new_client

# Function to retrieve known compounds associated with DYT1 dystonia
def retrieve_known_compounds():
    # Define targets associated with DYT1 dystonia (e.g., TOR1A)
    target_id = 'CHEMBL1829'  # Example: TOR1A target ID

    # Retrieve known compounds associated with the target
    target_client = new_client.target
    compounds = target_client.molecule_chembl_ids(target_id)
    return compounds

# Function to perform chemical similarity search
def perform_similarity_search(compounds, threshold=60):
    similarity_client = new_client.similarity
    similar_compounds_dict = {}

    for compound_id in compounds:
        # Perform similarity search using ChEMBL's similarity search API
        res = similarity_client.filter(smiles=compound_id, similarity=threshold).only(['molecule_chembl_id', 'similarity'])
        similar_compounds = [(entry['molecule_chembl_id'], round(float(entry['similarity']), 2)) for entry in res]
        similar_compounds_dict[compound_id] = similar_compounds

    return similar_compounds_dict

# Step 1: Retrieve known compounds associated with DYT1 dystonia
known_compounds = retrieve_known_compounds()

# Step 2: Perform chemical similarity search
similar_compounds_dict = perform_similarity_search(known_compounds)

# Step 3: Evaluate and prioritize similar compounds
# Example: Identify novel compounds with high similarity to known active compounds

# Step 4: Further analysis and experimental validation of prioritized compounds
# Example: Predict activity, drug-likeness, and experimental validation
